# %%
# !pip install easyocr

# %%
from __future__ import annotations

import argparse
import re
from collections import Counter
from dataclasses import dataclass
from pathlib import Path

import cv2
import easyocr
import pandas as pd


DEFAULT_VIDEO_PATH = "/kaggle/input/datasets/yerinim/basketball/1_.mp4"
DEFAULT_OUTPUT_PATH = "/kaggle/working/score_timeline_full_decimal_internal.csv"
DEFAULT_INTERVAL_SEC = 1.0
DEFAULT_CONFIRM_COUNT = 2
DEFAULT_RESYNC_COUNT = 3
MAX_RESYNC_SCORE_JUMP = 4
INITIAL_SCORE_WINDOW_SEC = 5.0
MISSING_CONFIRM_COUNT = 3
CUT_EDIT_MISSING_COUNT = 10
MAX_CLOCK_RESYNC_DROP_SEC = 60
MAX_CUT_CLOCK_RESYNC_DROP_SEC = 300  # long missing/cut resync limit
BIG_DROP_RESYNC_STUCK_SEC = 30.0  # visible-scoreboard big drop is allowed only after clock was stuck this long
REAPPEAR_CLOCK_RESYNC_BUFFER_SEC = 5.0  # allow clock drop after missing based on missing duration
VISIBLE_CLOCK_STUCK_REPEAT = 4  # same OCR clock repeats while scoreboard is visible
VISIBLE_CLOCK_STUCK_MAX_STEP_SEC = 1.0  # conservative recovery step
VISIBLE_CLOCK_FORCE_RESYNC_SEC = 8.0  # if visible scoreboard clock stays frozen this long, recover by elapsed time
VISIBLE_CLOCK_FORCE_MAX_STEP_SEC = 3.0  # max one-step visible stuck correction
MAX_NORMAL_CLOCK_DROP_SEC = 3
PENDING_CLOCK_RESYNC_COUNT = 3
CLOCK_ROI_MOTION_THRESHOLD = 0.8
CLOCK_ROI_MOTION_MIN_SECONDS = 2.0
CLOCK_ROI_MOTION_MAX_SECONDS = 12 * 60.0
CUT_EDIT_CLOCK_ADJUST_SEC = 5

MIN_OCR_CONFIDENCE = 0.25
MIN_INFO_OCR_CONFIDENCE = 0.10
MIN_NUMBER_HEIGHT = 12
MAX_SCORE_VALUE = 100
UNKNOWN = "UNKNOWN"

KNOWN_TEAM_CODES = {
    "ATL",
    "BKN",
    "BOS",
    "CHA",
    "CHI",
    "CLE",
    "DAL",
    "DEN",
    "DET",
    "GSW",
    "GS",
    "HOU",
    "IND",
    "LAC",
    "LAL",
    "MEM",
    "MIA",
    "MIL",
    "MIN",
    "NOP",
    "NYK",
    "NY",
    "OKC",
    "ORL",
    "PHI",
    "PHX",
    "POR",
    "SAC",
    "SAS",
    "SA",
    "TOR",
    "UTA",
    "WAS",
}

TEAM_OCR_ALIASES = {
    "UTAH": "UTA",
    "UIA": "UTA",
    "UT4": "UTA",
    "DENN": "DEN",
    "OEN": "DEN",
    "NETS": "BKN",
    "METS": "BKN",
    "NCTS": "BKN",
    "BROOKLYN": "BKN",
    "MAGIC": "ORL",
    "ORLANDO": "ORL",
}


@dataclass
class OcrItem:
    raw: str
    conf: float
    x: float
    y: float
    width: float
    height: float
    team: str
    roi: str = ""


@dataclass
class NumberCandidate:
    value: int
    raw: str
    conf: float
    x: float
    y: float
    width: float
    height: float
    roi: str = ""


@dataclass
class ParsedScoreboard:
    team1_score: int
    team2_score: int
    team1_name: str
    team2_name: str
    quarter: str
    game_clock: str
    region_score: float

    @property
    def score(self) -> tuple[int, int]:
        return self.team1_score, self.team2_score


@dataclass
class ClockRead:
    """Clock OCR result with decimal seconds kept internally."""
    display_clock: str
    seconds_float: float
    raw: str
    is_decimal: bool = False
    score: float = 0.0
    roi: str = ""


def parse_args() -> argparse.Namespace:
    parser = argparse.ArgumentParser(description="Extract basketball scoreboard OCR timeline.")
    parser.add_argument("--video", default=DEFAULT_VIDEO_PATH, help="Input mp4 video path")
    parser.add_argument("--output", default=DEFAULT_OUTPUT_PATH, help="Output CSV path")
    parser.add_argument("--team1", default=UNKNOWN, help="Manual left team name, e.g. DEN")
    parser.add_argument("--team2", default=UNKNOWN, help="Manual right team name, e.g. UTA")
    parser.add_argument(
        "--left-score-box",
        default="",
        help="Manual left score crop as x1,y1,x2,y2 ratios, e.g. 0.715,0.79,0.775,0.865",
    )
    parser.add_argument(
        "--right-score-box",
        default="",
        help="Manual right score crop as x1,y1,x2,y2 ratios, e.g. 0.835,0.79,0.895,0.865",
    )
    parser.add_argument("--interval", type=float, default=DEFAULT_INTERVAL_SEC, help="Sampling interval in seconds")
    parser.add_argument(
        "--confirm-count",
        type=int,
        default=DEFAULT_CONFIRM_COUNT,
        help="Number of repeated scores required for initial confirmation",
    )
    parser.add_argument(
        "--resync-count",
        type=int,
        default=DEFAULT_RESYNC_COUNT,
        help="Repeated non-decreasing invalid scores required to resync after missed samples",
    )
    parser.add_argument(
        "--record-mode",
        choices=["every-sample", "score-change"],
        default="score-change",
        help="CSV record mode",
    )
    parser.add_argument("--gpu", action="store_true", help="Use EasyOCR GPU mode")
    parser.add_argument("--debug", action="store_true", help="Print OCR number candidates")
    parser.add_argument(
        "--max-samples",
        type=int,
        default=0,
        help="Debug limit. 0 means full video; positive value limits OCR samples.",
    )
    parser.add_argument("--start-sec", type=float, default=None, help="Start time in seconds. None means from the beginning")
    parser.add_argument("--end-sec", type=float, default=None, help="End time in seconds. None means until the end")
    return parser.parse_args()


def parse_box_arg(value: str) -> tuple[float, float, float, float] | None:
    if not value:
        return None

    parts = [part.strip() for part in value.split(",")]
    if len(parts) != 4:
        raise ValueError(f"Box must have 4 comma-separated values: {value}")

    x1, y1, x2, y2 = (float(part) for part in parts)
    if not (0 <= x1 < x2 <= 1 and 0 <= y1 < y2 <= 1):
        raise ValueError(f"Box ratios must satisfy 0 <= x1 < x2 <= 1 and 0 <= y1 < y2 <= 1: {value}")

    return x1, y1, x2, y2


def bbox_bounds(bbox) -> tuple[float, float, float, float]:
    xs = [float(point[0]) for point in bbox]
    ys = [float(point[1]) for point in bbox]
    return min(xs), min(ys), max(xs), max(ys)


def normalize_quarter_text(text: str) -> str:
    compact = re.sub(r"[^0-9A-Z]", "", text.upper())
    compact = compact.replace("OQ", "0Q").replace("5T", "ST").replace("S1", "ST")

    suffix_only = {
        "ST": "1Q",
        "ND": "2Q",
        "RD": "3Q",
        "TH": "4Q",
    }
    for suffix, quarter in suffix_only.items():
        if compact == suffix or compact.endswith(suffix):
            return quarter

    match = re.fullmatch(r"([1-4])Q", compact)
    if match:
        return f"{match.group(1)}Q"

    if compact in {"OT", "0T"}:
        return "OT"

    ordinal_match = re.fullmatch(r"([1-4])(ST|ND|RD|TH)", compact)
    if ordinal_match:
        return f"{ordinal_match.group(1)}Q"

    return ""


def is_quarter_text(text: str) -> bool:
    return normalize_quarter_text(text) != ""


def normalize_game_clock_text(text: str) -> str:
    cleaned = text.upper().strip()
    cleaned = cleaned.replace("O", "0").replace("I", "1").replace("L", "1")

    # TNT 1분 미만 clock 처리
    # - 59.9, 50.2, 2.4 처럼 1초 초과 decimal은 초 단위 timeline으로 변환한다.
    #   예: 59.9 -> 00:59, 50.2 -> 00:50
    # - 1초 이하 decimal은 그대로 보존한다.
    #   예: 0.9 -> 0.9, 0.05 -> 0.05
    decimal_match = re.search(r"(?<!\d)(\d{1,2})\s*\.\s*(\d{1,2})(?!\d)", cleaned)
    if decimal_match:
        whole = int(decimal_match.group(1))
        frac_text = decimal_match.group(2)
        if 0 <= whole <= 59:
            # TNT 1분 미만 decimal은 내부적으로 소수까지 보존한다.
            # 예: 32.8을 바로 00:32로 바꿔버리면, 32.8 -> 32.1 변화가
            # 모두 같은 00:32처럼 보여서 OCR stuck처럼 멈춰 보일 수 있다.
            # 출력할 때만 1초 초과는 00:32 형식으로 정리한다.
            return f"{whole}.{frac_text}"

    cleaned = cleaned.replace("|", ":").replace(";", ":")

    match = re.search(r"(\d{1,2})\s*:\s*(\d{2})", cleaned)
    if not match:
        return ""

    minute = int(match.group(1))
    second = int(match.group(2))
    if 0 <= minute <= 15 and 0 <= second <= 59:
        return f"{minute:02d}:{second:02d}"
    return ""


def is_game_clock_text(text: str) -> bool:
    return normalize_game_clock_text(text) != ""


def game_clock_to_seconds(clock: str) -> float | None:
    text = str(clock).strip()

    # TNT 1분 미만 decimal: 59.9, 32.8, 1.2, 0.05 등
    # 내부 seconds 값은 소수까지 보존한다. 출력은 seconds_to_game_clock에서 정리한다.
    decimal_match = re.fullmatch(r"(\d{1,2})\.(\d{1,2})", text)
    if decimal_match:
        whole = int(decimal_match.group(1))
        frac_text = decimal_match.group(2)
        value = whole + int(frac_text) / (10 ** len(frac_text))
        if 0 <= value < 60:
            return float(value)

    match = re.fullmatch(r"(\d{1,2}):(\d{2})", text)
    if not match:
        return None

    minute = int(match.group(1))
    second = int(match.group(2))
    if 0 <= minute <= 15 and 0 <= second <= 59:
        return float(minute * 60 + second)
    return None


def seconds_to_game_clock(seconds: float) -> str:
    seconds = max(0.0, float(seconds))

    # 1초 이하는 decimal clock으로 표현할 수 있게 한다.
    # 0.05 같은 값은 두 자리 소수로 보존하고, 0.5 같은 값은 한 자리로 정리한다.
    if 0 < seconds <= 1.0:
        rounded_2 = round(seconds, 2)
        if rounded_2 < 0.1:
            return f"{rounded_2:.2f}"
        text = f"{rounded_2:.2f}".rstrip("0").rstrip(".")
        return text

    whole_seconds = max(0, int(seconds))
    return f"{whole_seconds // 60:02d}:{whole_seconds % 60:02d}"




def decimal_seconds_to_display(seconds_value: float, raw: str = "") -> str:
    seconds_value = max(0.0, float(seconds_value))
    if seconds_value <= 1.0:
        cleaned = str(raw).strip()
        cleaned = cleaned.replace("O", "0").replace("o", "0").replace(":", ".")
        match = re.search(r"\d+\.\d+", cleaned)
        if match:
            value = match.group(0)
            if value.startswith("00."):
                value = "0." + value.split(".", 1)[1]
            return value
        return f"{seconds_value:.2f}".rstrip("0").rstrip(".")
    return seconds_to_game_clock(int(seconds_value))


def normalize_game_clock_read(text: str) -> ClockRead | None:
    """Supports MM:SS and TNT decimal clocks: 59.9, 31.2, 0.9, 0.05."""
    raw = str(text).strip()
    if not raw:
        return None

    cleaned = raw.upper().strip()
    cleaned = cleaned.replace("O", "0").replace("I", "1").replace("L", "1")
    cleaned = cleaned.replace("|", ":").replace(";", ":")

    match = re.search(r"(\d{1,2})\s*:\s*(\d{2})", cleaned)
    if match:
        minute = int(match.group(1))
        second = int(match.group(2))
        if 0 <= minute <= 15 and 0 <= second <= 59:
            display = f"{minute:02d}:{second:02d}"
            return ClockRead(display, float(minute * 60 + second), raw, False)

    dec_match = re.search(r"(?<!\d)(\d{1,2})\s*\.\s*(\d{1,2})(?!\d)", cleaned)
    if dec_match:
        whole = int(dec_match.group(1))
        frac_text = dec_match.group(2)
        if 0 <= whole <= 59:
            seconds_value = float(f"{whole}.{frac_text}")
            if 0.0 <= seconds_value < 60.0:
                raw_decimal = f"{whole}.{frac_text}"
                return ClockRead(
                    display_clock=decimal_seconds_to_display(seconds_value, raw_decimal),
                    seconds_float=seconds_value,
                    raw=raw_decimal,
                    is_decimal=True,
                )

    return None


def clock_display_to_seconds_float(clock: str) -> float | None:
    value = str(clock).strip()
    mmss = game_clock_to_seconds(value)
    if mmss is not None:
        return float(mmss)
    if re.fullmatch(r"\d{1,2}\.\d{1,2}", value):
        sec = float(value)
        if 0.0 <= sec < 60.0:
            return sec
    return None


def quarter_to_number(quarter: str) -> int | None:
    text = str(quarter).upper().strip()
    match = re.fullmatch(r"([1-4])Q", text)
    if match:
        return int(match.group(1))
    if text == "OT":
        return 5
    return None


def normalize_stable_quarter(
    stable: dict[str, object],
    raw_quarter: str,
    raw_seconds: int | None,
) -> str:
    """Return a stable quarter value without trusting one-off OCR reads.

    Quarter OCR is noisy. A raw quarter can only move forward in order
    and the next quarter must be repeated while the clock looks like a
    quarter-start clock. Backward moves such as 2Q -> 1Q are ignored.
    """
    current = str(stable.get("quarter") or UNKNOWN)
    raw = raw_quarter or ""

    if not raw:
        return current

    raw_num = quarter_to_number(raw)
    current_num = quarter_to_number(current)

    if raw_num is None:
        return current

    # Initial quarter: use the first readable quarter as a starting point.
    if current_num is None:
        stable["quarter"] = raw
        stable["pending_quarter"] = None
        stable["pending_quarter_votes"] = 0
        return raw

    if raw_num == current_num:
        stable["pending_quarter"] = None
        stable["pending_quarter_votes"] = 0
        return current

    # Quarter cannot go backwards: 2Q -> 1Q, 3Q -> 2Q, etc.
    if raw_num < current_num:
        return current

    # Quarter cannot skip: 2Q -> 4Q is ignored.
    if raw_num != current_num + 1:
        return current

    # A real next quarter should appear with a quarter-start clock.
    # NBA periods start near 12:00, but after video cuts it can appear around 11:xx.
    if raw_seconds is None or not (9 * 60 <= raw_seconds <= 12 * 60):
        return current

    pending = stable.get("pending_quarter")
    votes = int(stable.get("pending_quarter_votes") or 0)
    if pending == raw:
        votes += 1
    else:
        pending = raw
        votes = 1

    stable["pending_quarter"] = pending
    stable["pending_quarter_votes"] = votes

    if votes >= 2:
        stable["quarter"] = raw
        stable["pending_quarter"] = None
        stable["pending_quarter_votes"] = 0
        return raw

    return current


def validate_game_clock_transition(prev_clock: str, new_clock: str) -> tuple[bool, str]:
    prev_seconds = game_clock_to_seconds(prev_clock)
    new_seconds = game_clock_to_seconds(new_clock)
    if prev_seconds is None or new_seconds is None:
        return False, prev_clock

    if prev_seconds == 0 and new_seconds > 0:
        return True, new_clock

    diff = prev_seconds - new_seconds
    if 0 <= diff <= 3:
        return True, new_clock
    return False, prev_clock


def normalize_team_name(text: str) -> str:
    compact = text.upper().replace(" ", "")
    if normalize_quarter_text(compact) or is_game_clock_text(compact):
        return ""

    cleaned = re.sub(r"[^A-Z]", "", compact)
    if len(cleaned) < 2:
        return ""
    if cleaned in {"ST", "ND", "RD", "TH", "Q", "QTR", "PER", "PTS", "TOL", "BON"}:
        return ""

    for alias, team in sorted(TEAM_OCR_ALIASES.items(), key=lambda value: len(value[0]), reverse=True):
        if alias in cleaned:
            return team

    for team in KNOWN_TEAM_CODES:
        if team in cleaned:
            return team

    return ""


def get_score_number_regions(frame) -> dict[str, object]:
    h, w = frame.shape[:2]
    return {
        "bottom_left_score_only": frame[
            int(h * 0.84) : int(h * 0.98),
            int(w * 0.10) : int(w * 0.45),
        ],
        "bottom_scorebar_left": frame[
            int(h * 0.78) : int(h * 0.98),
            0 : int(w * 0.55),
        ],
        "bottom_full": frame[
            int(h * 0.62) : h,
            0:w,
        ],
    }


def get_scoreboard_info_regions(frame) -> dict[str, object]:
    h, w = frame.shape[:2]
    return {
        "bottom_info_right": frame[
            int(h * 0.78) : int(h * 0.98),
            int(w * 0.30) : int(w * 0.90),
        ],
        "bottom_info_full": frame[
            int(h * 0.72) : h,
            0:w,
        ],
        "top_info_full": frame[
            0 : int(h * 0.35),
            0:w,
        ],
    }


def crop_by_ratio(frame, y1: float, y2: float, x1: float, x2: float):
    h, w = frame.shape[:2]
    top = max(0, min(h - 1, int(h * y1)))
    bottom = max(top + 1, min(h, int(h * y2)))
    left = max(0, min(w - 1, int(w * x1)))
    right = max(left + 1, min(w, int(w * x2)))
    return frame[top:bottom, left:right]


def crop_by_box(frame, box: tuple[float, float, float, float]):
    x1, y1, x2, y2 = box
    return crop_by_ratio(frame, y1, y2, x1, x2)


def get_clock_motion_crop(frame):
    """Return a fixed-size grayscale crop used only to detect clock-area motion.

    This does not read numbers. It checks whether the clock pixels changed.
    It helps distinguish:
    - real stoppage: OCR repeats same second and clock crop is almost unchanged
    - OCR stuck: OCR repeats same second but decimal digits in the clock crop keep changing
    """
    if frame is None or frame.size == 0:
        return None

    # TNT clock-only area. Keep this tight so player/crowd motion outside the clock
    # does not make a stopped clock look like it is running.
    crop = crop_by_ratio(frame, 0.775, 0.900, 0.710, 0.860)
    if crop is None or crop.size == 0:
        return None

    gray = cv2.cvtColor(crop, cv2.COLOR_BGR2GRAY)
    gray = cv2.resize(gray, (160, 48), interpolation=cv2.INTER_AREA)
    gray = cv2.GaussianBlur(gray, (3, 3), 0)
    return gray


def update_clock_roi_motion_state(stable: dict[str, object], frame) -> float:
    """Store how much the clock ROI changed from the previous valid scoreboard frame."""
    current_crop = get_clock_motion_crop(frame)
    previous_crop = stable.get("clock_motion_crop")

    if current_crop is None:
        stable["clock_roi_motion"] = 0.0
        stable["clock_roi_changed"] = False
        return 0.0

    if previous_crop is None:
        motion = 0.0
    else:
        diff_img = cv2.absdiff(current_crop, previous_crop)
        motion = float(diff_img.mean())

    stable["clock_motion_crop"] = current_crop
    stable["clock_roi_motion"] = motion
    stable["clock_roi_changed"] = motion >= CLOCK_ROI_MOTION_THRESHOLD
    return motion


def get_score_box_pairs(frame) -> dict[str, tuple[object, object]]:
    return {
        "espn_bottom_left": (
            crop_by_ratio(frame, 0.84, 0.94, 0.180, 0.245),
            crop_by_ratio(frame, 0.84, 0.94, 0.245, 0.325),
        ),
        "espn_bottom_left_wide": (
            crop_by_ratio(frame, 0.82, 0.95, 0.160, 0.250),
            crop_by_ratio(frame, 0.82, 0.95, 0.235, 0.340),
        ),
        "espn_bottom_left_low": (
            crop_by_ratio(frame, 0.86, 0.98, 0.170, 0.250),
            crop_by_ratio(frame, 0.86, 0.98, 0.235, 0.340),
        ),
        "tnt_bottom_right": (
            crop_by_ratio(frame, 0.79, 0.865, 0.715, 0.775),
            crop_by_ratio(frame, 0.79, 0.865, 0.835, 0.895),
        ),
        "tnt_bottom_right_wide": (
            crop_by_ratio(frame, 0.76, 0.89, 0.690, 0.790),
            crop_by_ratio(frame, 0.76, 0.89, 0.810, 0.905),
        ),
        "bally_bottom_center": (
            crop_by_ratio(frame, 0.84, 0.965, 0.130, 0.200),
            crop_by_ratio(frame, 0.84, 0.965, 0.300, 0.370),
        ),
        "bally_bottom_center_wide": (
            crop_by_ratio(frame, 0.80, 0.98, 0.105, 0.220),
            crop_by_ratio(frame, 0.80, 0.98, 0.270, 0.390),
        ),
    }


def get_team_name_box_pairs(frame) -> dict[str, tuple[object, object]]:
    return {
        "espn_bottom_left_teams": (
            crop_by_ratio(frame, 0.84, 0.94, 0.000, 0.175),
            crop_by_ratio(frame, 0.84, 0.94, 0.325, 0.450),
        ),
        "espn_bottom_left_teams_wide": (
            crop_by_ratio(frame, 0.80, 0.96, 0.000, 0.180),
            crop_by_ratio(frame, 0.80, 0.96, 0.320, 0.500),
        ),
        "tnt_bottom_right_teams": (
            crop_by_ratio(frame, 0.79, 0.865, 0.655, 0.715),
            crop_by_ratio(frame, 0.79, 0.865, 0.775, 0.835),
        ),
        "tnt_bottom_right_teams_wide": (
            crop_by_ratio(frame, 0.76, 0.89, 0.630, 0.720),
            crop_by_ratio(frame, 0.76, 0.89, 0.765, 0.835),
        ),
        "bally_bottom_center_teams": (
            crop_by_ratio(frame, 0.76, 0.96, 0.030, 0.135),
            crop_by_ratio(frame, 0.76, 0.96, 0.200, 0.305),
        ),
        "bally_bottom_center_teams_wide": (
            crop_by_ratio(frame, 0.72, 0.98, 0.000, 0.155),
            crop_by_ratio(frame, 0.72, 0.98, 0.185, 0.330),
        ),
    }


def preprocess_for_ocr(region_img):
    h, w = region_img.shape[:2]
    scale = 1.5 if max(h, w) < 900 else 1.0
    image = region_img

    if scale != 1.0:
        image = cv2.resize(image, None, fx=scale, fy=scale, interpolation=cv2.INTER_CUBIC)

    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    enhanced = cv2.convertScaleAbs(gray, alpha=1.35, beta=8)
    return enhanced, scale


def read_ocr_items(
    reader: easyocr.Reader,
    region_img,
    min_confidence: float = MIN_OCR_CONFIDENCE,
    allowlist: str | None = None,
) -> list[OcrItem]:
    processed, scale = preprocess_for_ocr(region_img)
    read_kwargs = {"detail": 1, "paragraph": False}
    if allowlist:
        read_kwargs["allowlist"] = allowlist
    results = reader.readtext(processed, **read_kwargs)
    items: list[OcrItem] = []

    for bbox, text, conf in results:
        raw = str(text).strip()
        if conf < min_confidence or not raw:
            continue

        x1, y1, x2, y2 = bbox_bounds(bbox)
        x1 /= scale
        y1 /= scale
        x2 /= scale
        y2 /= scale

        items.append(
            OcrItem(
                raw=raw,
                conf=float(conf),
                x=(x1 + x2) / 2,
                y=(y1 + y2) / 2,
                width=x2 - x1,
                height=y2 - y1,
                team=normalize_team_name(raw),
            )
        )

    return items


def read_score_number_items(reader: easyocr.Reader, region_img) -> list[OcrItem]:
    items = read_ocr_items(
        reader,
        region_img,
        min_confidence=MIN_INFO_OCR_CONFIDENCE,
        allowlist="0123456789",
    )
    for item in items:
        item.roi = "score_numbers"
    return items


def read_scoreboard_info_items(reader: easyocr.Reader, frame) -> list[OcrItem]:
    items: list[OcrItem] = []
    for region_name, region_img in get_scoreboard_info_regions(frame).items():
        region_items = read_ocr_items(
            reader,
            region_img,
            min_confidence=MIN_INFO_OCR_CONFIDENCE,
        )
        for item in region_items:
            item.roi = region_name
        items.extend(region_items)
    return items


def score_box_ocr_inputs(region_img, side: str) -> list[tuple[object, float, str]]:
    inputs: list[tuple[object, float, str]] = [(region_img, 1.0, "original")]

    if side == "right":
        enlarged = cv2.resize(region_img, None, fx=3.0, fy=3.0, interpolation=cv2.INTER_CUBIC)
        enlarged = cv2.copyMakeBorder(
            enlarged,
            8,
            8,
            8,
            8,
            cv2.BORDER_CONSTANT,
            value=(0, 0, 0),
        )
        inputs.append((enlarged, 3.0, "right_enlarged"))

    return inputs


def read_single_score_value(reader: easyocr.Reader, region_img, side: str = "left") -> tuple[int, str, float] | None:
    candidates: list[NumberCandidate] = []

    for image, scale, source in score_box_ocr_inputs(region_img, side):
        results = reader.readtext(
            image,
            detail=1,
            paragraph=False,
            allowlist="0123456789",
        )

        for bbox, text, conf in results:
            numeric = normalize_numeric_text(str(text))
            if not re.fullmatch(r"\d{1,3}", numeric):
                continue

            value = int(numeric)
            if value > MAX_SCORE_VALUE:
                continue

            x1, y1, x2, y2 = bbox_bounds(bbox)
            candidates.append(
                NumberCandidate(
                    value=value,
                    raw=str(text),
                    conf=float(conf),
                    x=((x1 + x2) / 2) / scale,
                    y=((y1 + y2) / 2) / scale,
                    width=(x2 - x1) / scale,
                    height=(y2 - y1) / scale,
                    roi=source,
                )
            )

    if not candidates:
        return None

    candidates.sort(
        key=lambda item: (
            item.conf + (0.08 if item.roi == "right_enlarged" else 0.0),
            item.height * item.conf,
        ),
        reverse=True,
    )
    best = candidates[0]
    return best.value, best.raw, best.conf


def read_single_team_name(reader: easyocr.Reader, region_img) -> tuple[str, str, float] | None:
    results = reader.readtext(
        region_img,
        detail=1,
        paragraph=False,
        allowlist="ABCDEFGHIJKLMNOPQRSTUVWXYZ",
    )
    candidates: list[tuple[float, str, str, float]] = []

    for bbox, text, conf in results:
        team = normalize_team_name(str(text))
        if not team:
            continue

        x1, y1, x2, y2 = bbox_bounds(bbox)
        width = x2 - x1
        height = y2 - y1
        score = float(conf) * 20.0 + min(width, 160) * 0.03 + height * 0.05
        candidates.append((score, team, str(text), float(conf)))

    if not candidates:
        return None

    candidates.sort(key=lambda value: value[0], reverse=True)
    _, team, raw, conf = candidates[0]
    return team, raw, conf


def extract_team_names_from_boxes(reader: easyocr.Reader, frame, debug: bool = False) -> tuple[str, str]:
    best_pair = ("", "")
    best_score = float("-inf")

    for region_name, (left_img, right_img) in get_team_name_box_pairs(frame).items():
        left_team = read_single_team_name(reader, left_img)
        right_team = read_single_team_name(reader, right_img)

        if debug:
            print(f"        {region_name}: left_team={left_team}, right_team={right_team}")

        score = 0.0
        if left_team:
            score += left_team[2] * 20.0 + 10.0
        if right_team:
            score += right_team[2] * 20.0 + 10.0
        if left_team and right_team:
            score += 15.0

        if score > best_score:
            best_score = score
            best_pair = (
                left_team[0] if left_team else "",
                right_team[0] if right_team else "",
            )

    return best_pair


def extract_team_names_from_info_items(items: list[OcrItem]) -> tuple[str, str]:
    team_items = [item for item in items if item.team]
    team_items.sort(key=lambda item: item.x)

    teams: list[str] = []
    for item in team_items:
        if item.team not in teams:
            teams.append(item.team)

    if len(teams) >= 2:
        return teams[0], teams[1]
    if len(teams) == 1:
        return teams[0], ""
    return "", ""


def normalize_numeric_text(text: str) -> str:
    cleaned = text.upper().strip()
    cleaned = cleaned.translate(
        str.maketrans(
            {
                "O": "0",
                "D": "0",
                "I": "1",
                "L": "1",
                "Z": "2",
                "A": "4",
                "S": "5",
                "G": "6",
                "B": "8",
            }
        )
    )
    return re.sub(r"[^0-9]", "", cleaned)


def extract_number_candidates(items: list[OcrItem]) -> list[NumberCandidate]:
    candidates: list[NumberCandidate] = []

    for item in items:
        raw = item.raw
        compact = raw.upper().replace(" ", "")

        if item.team:
            continue
        if is_quarter_text(raw):
            continue
        if is_game_clock_text(raw):
            continue
        if re.fullmatch(r"[A-Z]+", compact):
            continue

        pair_match = re.fullmatch(r"\s*([0-9A-Z]{1,3})\s*[:|]\s*([0-9A-Z]{1,3})\s*", compact)
        if pair_match:
            left_text = normalize_numeric_text(pair_match.group(1))
            right_text = normalize_numeric_text(pair_match.group(2))
            if not re.fullmatch(r"\d{1,3}", left_text) or not re.fullmatch(r"\d{1,3}", right_text):
                continue

            left = int(left_text)
            right = int(right_text)
            if 0 <= left <= MAX_SCORE_VALUE and 0 <= right <= MAX_SCORE_VALUE:
                candidates.append(
                    NumberCandidate(
                        left,
                        raw,
                        item.conf,
                        item.x - item.width * 0.25,
                        item.y,
                        item.width / 2,
                        item.height,
                        item.roi,
                    )
                )
                candidates.append(
                    NumberCandidate(
                        right,
                        raw,
                        item.conf,
                        item.x + item.width * 0.25,
                        item.y,
                        item.width / 2,
                        item.height,
                        item.roi,
                    )
                )
            continue

        numeric = normalize_numeric_text(raw)
        if re.fullmatch(r"\d{4,6}", numeric):
            split_positions = [len(numeric) // 2]
            if len(numeric) == 5:
                split_positions = [2, 3]

            for split_at in split_positions:
                left_text = numeric[:split_at]
                right_text = numeric[split_at:]
                if not (1 <= len(left_text) <= 3 and 1 <= len(right_text) <= 3):
                    continue

                left = int(left_text)
                right = int(right_text)
                if 0 <= left <= MAX_SCORE_VALUE and 0 <= right <= MAX_SCORE_VALUE:
                    candidates.append(
                        NumberCandidate(
                            left,
                            raw,
                            item.conf,
                            item.x - item.width * 0.25,
                            item.y,
                            item.width / 2,
                            item.height,
                            item.roi,
                        )
                    )
                    candidates.append(
                        NumberCandidate(
                            right,
                            raw,
                            item.conf,
                            item.x + item.width * 0.25,
                            item.y,
                            item.width / 2,
                            item.height,
                            item.roi,
                        )
                    )
            continue

        if not re.fullmatch(r"\d{1,3}", numeric):
            continue

        value = int(numeric)
        if value > MAX_SCORE_VALUE:
            continue
        if item.height < MIN_NUMBER_HEIGHT:
            continue

        candidates.append(NumberCandidate(value, raw, item.conf, item.x, item.y, item.width, item.height, item.roi))

    return candidates


def deduplicate_numbers(candidates: list[NumberCandidate]) -> list[NumberCandidate]:
    sorted_candidates = sorted(candidates, key=lambda n: (n.height * n.conf, n.height), reverse=True)
    unique: list[NumberCandidate] = []

    for candidate in sorted_candidates:
        duplicated = False
        for saved in unique:
            same_value = candidate.value == saved.value
            close_x = abs(candidate.x - saved.x) <= max(candidate.width, saved.width)
            close_y = abs(candidate.y - saved.y) <= max(candidate.height, saved.height) * 0.6
            if same_value and close_x and close_y:
                duplicated = True
                break

        if not duplicated:
            unique.append(candidate)

    return unique


def is_obvious_bad_pair(left: NumberCandidate, right: NumberCandidate) -> bool:
    small = min(left.value, right.value)
    big = max(left.value, right.value)
    return small <= 4 and big >= 20


def choose_score_pair(candidates: list[NumberCandidate]) -> tuple[tuple[NumberCandidate, NumberCandidate] | None, float]:
    if len(candidates) < 2:
        return None, 0.0

    tallest = max(candidate.height for candidate in candidates)
    large_candidates = [
        candidate
        for candidate in candidates
        if candidate.height >= max(MIN_NUMBER_HEIGHT, tallest * 0.55)
    ]
    search_candidates = large_candidates if len(large_candidates) >= 2 else candidates

    best_pair = None
    best_score = float("-inf")

    score_roi_bonus = {
        "score_numbers": 45.0,
        "team1_score": 32.0,
        "team2_score": 32.0,
        "score_pair": 22.0,
    }
    info_rois = {"center_info", "middle_info", "right_info"}

    for i, first in enumerate(search_candidates):
        for second in search_candidates[i + 1 :]:
            left, right = sorted([first, second], key=lambda n: n.x)
            if is_obvious_bad_pair(left, right):
                continue

            x_gap = right.x - left.x
            y_gap = abs(right.y - left.y)
            max_height = max(left.height, right.height)
            min_height = min(left.height, right.height)
            height_ratio = min_height / max_height

            if x_gap < max_height * 0.7:
                continue
            if y_gap > max_height * 0.75:
                continue
            if height_ratio < 0.58:
                continue

            pair_score = 0.0
            pair_score += (left.height + right.height) * 2.4
            pair_score += (left.conf + right.conf) * 12
            pair_score += height_ratio * 25
            pair_score += score_roi_bonus.get(left.roi, 0.0)
            pair_score += score_roi_bonus.get(right.roi, 0.0)
            pair_score += 18.0 if {left.roi, right.roi} == {"team1_score", "team2_score"} else 0.0
            pair_score -= 22.0 if left.roi in info_rois else 0.0
            pair_score -= 22.0 if right.roi in info_rois else 0.0
            pair_score -= y_gap * 0.7
            pair_score -= x_gap * 0.025

            if pair_score > best_score:
                best_score = pair_score
                best_pair = (left, right)

    if best_pair is None:
        return None, 0.0

    return best_pair, best_score


def extract_quarter(items: list[OcrItem]) -> str:
    quarter_candidates: list[tuple[float, str]] = []

    for item in items:
        quarter = normalize_quarter_text(item.raw)
        if quarter:
            score = item.conf * 20.0
            score += 20.0 if item.roi in {"center_info", "middle_info", "right_info"} else 0.0
            score += 8.0 if re.search(r"(?i)(st|nd|rd|th|q|ot)", item.raw) else 0.0
            score -= item.height * 0.03
            quarter_candidates.append((score, quarter))

    if not quarter_candidates:
        return ""

    quarter_candidates.sort(key=lambda value: value[0], reverse=True)
    return quarter_candidates[0][1]


def extract_game_clock(items: list[OcrItem]) -> str:
    clock_candidates: list[tuple[float, str]] = []

    for item in items:
        clock = normalize_game_clock_text(item.raw)
        clock_seconds = game_clock_to_seconds(clock) if clock else None
        if clock_seconds is None:
            continue

        score = 0.0
        score += item.conf * 20.0
        score += 25.0 if item.roi == "center_info" else 0.0
        score += 8.0 if item.height < 45 else 0.0
        score += 6.0 if re.search(r"[:|;.]", item.raw) else 0.0
        score -= item.height * 0.05
        clock_candidates.append((score, clock))

    if not clock_candidates:
        return ""

    clock_candidates.sort(key=lambda value: value[0], reverse=True)
    return clock_candidates[0][1]


def get_clock_box_regions(frame) -> dict[str, object]:
    """경기시간 OCR 전용 crop 후보.

    05:24에서 직접 확인한 좌표를 반영했다.
    기준은 TNT 하단 점수판 전체가 보이는 영역이며,
    clock_only / clock_wide 후보를 같이 OCR해서 가장 clock처럼 읽히는 값을 고른다.
    """
    return {
        # 방금 좌표 튜닝으로 확인한 후보들
        "tnt_scoreboard_full": crop_by_ratio(frame, 0.775, 0.900, 0.600, 0.860),
        "tnt_clock_only": crop_by_ratio(frame, 0.785, 0.885, 0.745, 0.835),
        "tnt_clock_wide": crop_by_ratio(frame, 0.775, 0.900, 0.710, 0.860),

        # 조금 더 넓은 fallback. 컷마다 위치가 살짝 흔들릴 때 대비.
        "tnt_scoreboard_full_wide": crop_by_ratio(frame, 0.765, 0.910, 0.575, 0.885),
        "tnt_clock_wide_safe": crop_by_ratio(frame, 0.765, 0.910, 0.690, 0.875),

        # 다른 방송사 하단 좌측/중앙 점수판 후보
        "espn_clock_left": crop_by_ratio(frame, 0.855, 0.955, 0.320, 0.455),
        "espn_clock_left_wide": crop_by_ratio(frame, 0.835, 0.970, 0.290, 0.490),
        "bally_clock_center": crop_by_ratio(frame, 0.865, 0.970, 0.205, 0.330),
        "bally_clock_center_wide": crop_by_ratio(frame, 0.835, 0.985, 0.175, 0.365),
    }

def preprocess_clock_for_ocr(region_img):
    """경기시간 OCR 전용 전처리.

    이전 버전의 4배 확대는 crop이 틀렸을 때 ASSIST 같은 큰 글자를 더 크게 만들어서
    OCR이 그쪽에 끌리는 문제가 있었다. 그래서 2배 확대를 기본으로 낮추고,
    원본 비율을 크게 해치지 않는 후보들을 만든다.
    """
    if region_img is None or region_img.size == 0:
        return []

    variants = []

    # 너무 크게 키우지 않음: 4.0 -> 2.0
    enlarged = cv2.resize(region_img, None, fx=2.0, fy=2.0, interpolation=cv2.INTER_CUBIC)
    gray = cv2.cvtColor(enlarged, cv2.COLOR_BGR2GRAY)

    enhanced = cv2.convertScaleAbs(gray, alpha=1.45, beta=8)
    variants.append(enhanced)

    # 약한 이진화 후보
    _, binary = cv2.threshold(enhanced, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
    variants.append(binary)
    variants.append(cv2.bitwise_not(binary))

    # 약간 더 선명하게 한 후보
    sharp = cv2.GaussianBlur(enhanced, (0, 0), 1.0)
    sharp = cv2.addWeighted(enhanced, 1.6, sharp, -0.6, 0)
    variants.append(sharp)

    return variants

def read_game_clock_from_dedicated_boxes(reader: easyocr.Reader, frame, debug: bool = False) -> str:
    """전용 clock ROI에서 경기시간을 먼저 읽는다.

    반환값이 빈 문자열이면 기존 bottom_info OCR 결과를 fallback으로 사용한다.
    """
    candidates: list[tuple[float, str, str, str, float]] = []

    for region_name, region_img in get_clock_box_regions(frame).items():
        for variant_idx, processed in enumerate(preprocess_clock_for_ocr(region_img)):
            results = reader.readtext(
                processed,
                detail=1,
                paragraph=False,
                allowlist="0123456789:|;.",
            )
            for bbox, text, conf in results:
                raw = str(text).strip()
                clock = normalize_game_clock_text(raw)
                seconds = game_clock_to_seconds(clock) if clock else None
                if seconds is None:
                    continue

                x1, y1, x2, y2 = bbox_bounds(bbox)
                width = x2 - x1
                height = y2 - y1

                # 전용 crop에서는 :가 있거나, 3~5글자 길이인 값이 clock일 가능성이 높다.
                score = float(conf) * 100.0
                score += 35.0 if re.search(r"[:|;.]", raw) else 0.0
                score += 35.0 if region_name == "tnt_clock_only" else 0.0
                score += 25.0 if region_name == "tnt_clock_wide" else 0.0
                score += 18.0 if region_name == "tnt_scoreboard_full" else 0.0
                score += 10.0 if "safe" in region_name else 0.0
                score += 6.0 if region_name.endswith("wide") else 0.0
                score += min(width, 260) * 0.02 + min(height, 120) * 0.02
                score -= 4.0 * variant_idx
                candidates.append((score, clock, raw, region_name, float(conf)))

    if debug:
        dbg = ", ".join(
            f"{clock}(raw={raw},roi={roi},conf={conf:.2f},score={score:.1f})"
            for score, clock, raw, roi, conf in sorted(candidates, reverse=True)[:8]
        )
        print(f"        dedicated clock OCR: {dbg}")

    if not candidates:
        return ""

    candidates.sort(key=lambda value: value[0], reverse=True)
    return candidates[0][1]


def extract_scoreboard_info(reader: easyocr.Reader, frame, debug: bool = False) -> tuple[str, str, tuple[str, str]]:
    items = read_scoreboard_info_items(reader, frame)

    if debug:
        raw_items = ", ".join(f"{item.raw}(roi={item.roi},conf={item.conf:.2f})" for item in items)
        print(f"        info OCR: {raw_items}")

    # 경기시간은 점수/팀명/shot clock과 섞이면 OCR이 자주 실패하므로
    # 전용 clock ROI를 먼저 읽고, 실패할 때만 기존 info OCR로 fallback한다.
    dedicated_clock = read_game_clock_from_dedicated_boxes(reader, frame, debug=debug)
    fallback_clock = extract_game_clock(items)
    game_clock = dedicated_clock or fallback_clock

    return extract_quarter(items), game_clock, extract_team_names_from_info_items(items)


def score_box_pair_quality(
    left_value: tuple[int, str, float],
    right_value: tuple[int, str, float],
    region_name: str,
) -> float:
    left_score, _left_raw, left_conf = left_value
    right_score, _right_raw, right_conf = right_value

    quality = (left_conf + right_conf) * 100.0
    quality += 30.0 if left_score >= 10 else -25.0
    quality += 30.0 if right_score >= 10 else -25.0
    quality += 10.0 if 0 <= left_score <= MAX_SCORE_VALUE else -100.0
    quality += 10.0 if 0 <= right_score <= MAX_SCORE_VALUE else -100.0

    if region_name.endswith("_wide"):
        quality -= 8.0
    if region_name.endswith("_low"):
        quality -= 12.0

    return quality


def parse_region(items: list[OcrItem]) -> tuple[ParsedScoreboard | None, list[NumberCandidate]]:
    numbers = deduplicate_numbers(extract_number_candidates(items))
    pair, pair_score = choose_score_pair(numbers)
    if pair is None:
        return None, numbers

    left, right = sorted(pair, key=lambda n: n.x)
    team1_name, team2_name = "", ""
    quarter = extract_quarter(items)
    game_clock = extract_game_clock(items)

    region_score = pair_score
    region_score += len(numbers) * 1.5
    region_score += 8 if game_clock else 0
    region_score += 6 if quarter else 0

    return (
        ParsedScoreboard(
            team1_score=left.value,
            team2_score=right.value,
            team1_name=team1_name,
            team2_name=team2_name,
            quarter=quarter,
            game_clock=game_clock,
            region_score=region_score,
        ),
        numbers,
    )


def choose_best_region(
    reader: easyocr.Reader,
    frame,
    debug: bool = False,
    manual_score_boxes: tuple[tuple[float, float, float, float], tuple[float, float, float, float]] | None = None,
    known_team_names: tuple[str, str] | None = None,
) -> tuple[str, ParsedScoreboard] | None:
    quarter, game_clock, info_teams = extract_scoreboard_info(reader, frame, debug=debug)
    info_team1, info_team2 = info_teams
    known_team1 = ""
    known_team2 = ""
    if known_team_names is not None:
        known_team1, known_team2 = known_team_names
        known_team1 = "" if known_team1 == UNKNOWN else known_team1
        known_team2 = "" if known_team2 == UNKNOWN else known_team2

    box_team1 = ""
    box_team2 = ""
    if not known_team1 or not known_team2:
        box_team1, box_team2 = extract_team_names_from_boxes(reader, frame, debug=debug)

    team1_name = known_team1 or box_team1 or info_team1
    team2_name = known_team2 or box_team2 or info_team2
    best_box_result: tuple[str, ParsedScoreboard] | None = None
    best_box_quality = float("-inf")

    score_box_pairs = {}
    if manual_score_boxes is not None:
        left_box, right_box = manual_score_boxes
        score_box_pairs["manual_score_boxes"] = (crop_by_box(frame, left_box), crop_by_box(frame, right_box))
    score_box_pairs.update(get_score_box_pairs(frame))

    for region_name, (left_img, right_img) in score_box_pairs.items():
        left_value = read_single_score_value(reader, left_img, side="left")
        right_value = read_single_score_value(reader, right_img, side="right")

        if debug:
            print(f"        {region_name}: left={left_value}, right={right_value}")

        if left_value is None or right_value is None:
            continue

        left_score, left_raw, left_conf = left_value
        right_score, right_raw, right_conf = right_value
        if is_obvious_bad_pair(
            NumberCandidate(left_score, left_raw, left_conf, 0, 0, 1, 1),
            NumberCandidate(right_score, right_raw, right_conf, 1, 0, 1, 1),
        ):
            continue

        quality = score_box_pair_quality(left_value, right_value, region_name)
        if region_name == "manual_score_boxes":
            quality += 50.0
        parsed = ParsedScoreboard(
            team1_score=left_score,
            team2_score=right_score,
            team1_name=team1_name,
            team2_name=team2_name,
            quarter=quarter,
            game_clock=game_clock,
            region_score=quality,
        )

        if quality > best_box_quality:
            best_box_quality = quality
            best_box_result = (region_name, parsed)

    if best_box_result is not None:
        return best_box_result

    for region_name, region_img in get_score_number_regions(frame).items():
        items = read_score_number_items(reader, region_img)
        parsed, numbers = parse_region(items)

        if debug:
            debug_numbers = ", ".join(
                f"{n.value}(raw={n.raw},roi={n.roi},h={n.height:.1f},x={n.x:.0f},y={n.y:.0f})"
                for n in numbers
            )
            print(f"        {region_name}: {debug_numbers}")

        if parsed is None:
            continue

        parsed.quarter = quarter
        parsed.game_clock = game_clock
        parsed.team1_name = team1_name
        parsed.team2_name = team2_name

        return region_name, parsed

    return None


def is_valid_score_transition(new_score: tuple[int, int], last_score: tuple[int, int] | None) -> bool:
    new_a, new_b = new_score

    if is_obvious_bad_pair(
        NumberCandidate(new_a, str(new_a), 1.0, 0, 0, 1, 1),
        NumberCandidate(new_b, str(new_b), 1.0, 1, 0, 1, 1),
    ):
        return False

    if last_score is None:
        return True

    last_a, last_b = last_score
    diff_a = new_a - last_a
    diff_b = new_b - last_b

    if diff_a < 0 or diff_b < 0:
        return False
    if diff_a == 0 and diff_b == 0:
        return True
    if diff_a in (1, 2, 3) and diff_b == 0:
        return True
    if diff_b in (1, 2, 3) and diff_a == 0:
        return True
    return False


def one_digit_off(value: int, target: int) -> bool:
    value_text = str(value)
    target_text = str(target)
    if len(value_text) != len(target_text):
        return False
    return sum(a != b for a, b in zip(value_text, target_text)) == 1


def plausible_single_digit_score_error(value: int, target: int) -> bool:
    return one_digit_off(value, target) and abs(value - target) <= 10


def infer_plausible_score_from_ocr_error(
    new_score: tuple[int, int],
    last_score: tuple[int, int] | None,
) -> tuple[int, int] | None:
    if last_score is None or is_valid_score_transition(new_score, last_score):
        return None

    new_a, new_b = new_score
    last_a, last_b = last_score
    if new_b == last_b and new_a > last_a + 3:
        for target_a in (last_a + 1, last_a + 2, last_a + 3):
            if plausible_single_digit_score_error(new_a, target_a):
                return target_a, last_b

    if new_a == last_a and new_b > last_b + 3:
        for target_b in (last_b + 1, last_b + 2, last_b + 3):
            if plausible_single_digit_score_error(new_b, target_b):
                return last_a, target_b

    return None


def is_plausible_resync_score(new_score: tuple[int, int], last_score: tuple[int, int] | None) -> bool:
    if last_score is None or is_valid_score_transition(new_score, last_score):
        return False

    new_a, new_b = new_score
    last_a, last_b = last_score
    diff_a = new_a - last_a
    diff_b = new_b - last_b

    if diff_a < 0 or diff_b < 0:
        return False
    if diff_a > MAX_RESYNC_SCORE_JUMP or diff_b > MAX_RESYNC_SCORE_JUMP:
        return False
    if is_obvious_bad_pair(
        NumberCandidate(new_a, str(new_a), 1.0, 0, 0, 1, 1),
        NumberCandidate(new_b, str(new_b), 1.0, 1, 0, 1, 1),
    ):
        return False

    return diff_a > 0 or diff_b > 0


def with_score(parsed: ParsedScoreboard, score: tuple[int, int]) -> ParsedScoreboard:
    return ParsedScoreboard(
        team1_score=score[0],
        team2_score=score[1],
        team1_name=parsed.team1_name,
        team2_name=parsed.team2_name,
        quarter=parsed.quarter,
        game_clock=parsed.game_clock,
        region_score=parsed.region_score,
    )


def format_analysis_time(time_sec: float) -> str:
    total_seconds = max(0, int(round(time_sec)))
    hours = total_seconds // 3600
    minutes = (total_seconds % 3600) // 60
    seconds = total_seconds % 60
    return f"{hours:02d}:{minutes:02d}:{seconds:02d}"


def is_valid_scoreboard_candidate(
    parsed: ParsedScoreboard,
    last_confirmed_score: tuple[int, int] | None = None,
) -> bool:
    """Return True only when the OCR result looks like a real scoreboard.

    Text graphics such as "AUDIO ASSIST" can contain random numbers and may
    appear near the real TNT clock/quarter area. Therefore context alone
    (clock or quarter) is not enough. After the initial score is confirmed,
    the raw score must also be compatible with basketball score rules from
    the last confirmed score.
    """
    has_scores = (
        isinstance(parsed.team1_score, int)
        and isinstance(parsed.team2_score, int)
        and 0 <= parsed.team1_score <= MAX_SCORE_VALUE
        and 0 <= parsed.team2_score <= MAX_SCORE_VALUE
        and not is_obvious_bad_pair(
            NumberCandidate(parsed.team1_score, str(parsed.team1_score), 1.0, 0, 0, 1, 1),
            NumberCandidate(parsed.team2_score, str(parsed.team2_score), 1.0, 1, 0, 1, 1),
        )
    )

    has_clock = game_clock_to_seconds(parsed.game_clock) is not None
    has_quarter = normalize_quarter_text(parsed.quarter) != ""

    if not (has_scores and (has_clock or has_quarter)):
        return False

    # Before the first confirmed score, use the general scoreboard context only.
    if last_confirmed_score is None:
        return True

    raw_score = parsed.score

    # Same score or normal +1/+2/+3 score change is a possible real scoreboard.
    if is_valid_score_transition(raw_score, last_confirmed_score):
        return True

    # Keep candidates that can be corrected by the existing OCR correction logic
    # such as raw 62:45 -> corrected 52:45.
    if infer_plausible_score_from_ocr_error(raw_score, last_confirmed_score) is not None:
        return True

    # Keep repeated plausible resync candidates. Completely impossible random
    # ad/lower-third numbers will be rejected before reaching score logic.
    if is_plausible_resync_score(raw_score, last_confirmed_score):
        return True

    return False



def handle_scoreboard_missing(
    stable: dict[str, object],
    time_sec: float,
    reader: easyocr.Reader | None = None,
    frame=None,
) -> str:
    """Update state when the full scoreboard/score pair is not detected.

    Conservative rule:
    - Do NOT move the game clock during ordinary missing frames.
    - This preserves the earlier stable behavior where real stoppages stay fixed.
    - Missing count is still tracked.
    - If missing lasts long enough, the clock is resynced when the scoreboard returns
      in apply_long_missing_clock_resync_if_needed().
    """
    last_seconds = stable.get("game_clock_seconds")
    last_clock = str(stable.get("game_clock") or UNKNOWN)

    missing_count = int(stable.get("scoreboard_missing_count") or 0) + 1
    stable["scoreboard_missing_count"] = missing_count
    stable["scoreboard_was_missing"] = True
    stable["scoreboard_missing_confirmed"] = missing_count >= MISSING_CONFIRM_COUNT

    if not isinstance(last_seconds, (int, float)):
        stable["scoreboard_missing_start_seconds"] = None
        stable["scoreboard_missing_start_clock"] = last_clock
        stable["game_clock_time"] = time_sec
        stable["clock_state"] = "UNKNOWN_WHILE_MISSING"
        return last_clock

    if missing_count == 1:
        stable["scoreboard_missing_start_seconds"] = float(last_seconds)
        stable["scoreboard_missing_start_clock"] = seconds_to_game_clock(float(last_seconds))

    # Ordinary missing: keep previous clock.
    # Long missing is handled only when the scoreboard reappears.
    new_seconds = float(last_seconds)
    game_clock = (
        decimal_seconds_to_display(new_seconds, last_clock)
        if new_seconds <= 1.0 and re.fullmatch(r"\d{1,2}\.\d{1,2}", last_clock)
        else seconds_to_game_clock(new_seconds)
    )

    stable["game_clock"] = game_clock
    stable["game_clock_seconds"] = new_seconds
    stable["game_clock_time"] = time_sec
    stable["clock_state"] = "HOLD_WHILE_MISSING"
    return game_clock


def apply_stable_context(parsed: ParsedScoreboard, stable: dict[str, object], time_sec: float) -> ParsedScoreboard:
    last_team1 = str(stable.get("team1_name") or "")
    last_team2 = str(stable.get("team2_name") or "")
    if last_team1 == UNKNOWN:
        last_team1 = ""
    if last_team2 == UNKNOWN:
        last_team2 = ""

    if parsed.team1_name and not last_team1:
        stable["team1_name"] = parsed.team1_name
        last_team1 = parsed.team1_name
    if parsed.team2_name and not last_team2:
        stable["team2_name"] = parsed.team2_name
        last_team2 = parsed.team2_name

    team1 = last_team1 or parsed.team1_name or UNKNOWN
    team2 = last_team2 or parsed.team2_name or UNKNOWN

    raw_quarter = parsed.quarter or ""
    raw_clock = parsed.game_clock
    raw_seconds = clock_display_to_seconds_float(raw_clock) if raw_clock else None

    quarter = normalize_stable_quarter(stable, raw_quarter, raw_seconds)

    last_seconds = stable.get("game_clock_seconds")

    if raw_seconds is not None and not isinstance(last_seconds, (int, float)):
        new_seconds = raw_seconds
        clock_state = "OBSERVED_INITIAL"
        stable["pending_clock_resync_seconds"] = None
        stable["pending_clock_resync_votes"] = 0

    elif isinstance(last_seconds, (int, float)):
        # 최종 clock 기준:
        # - OCR이 실제로 읽은 clock을 우선한다.
        # - 같은 clock이 반복되면 실제 경기 정지로 보고 유지한다.
        # - scoreboard/clock OCR 실패면 유지한다.
        # - 1초 이하 decimal(0.9, 0.05 등)은 그대로 허용한다.
        # - 큰 점프는 바로 믿지 않고 반복 확인 후 resync한다.
        # - 이전 버전처럼 무조건 -1초 예측 감소는 하지 않는다.
        if raw_seconds is None:
            new_seconds = float(last_seconds)
            clock_state = "HOLD_NO_CLOCK_OCR"
        else:
            diff = float(last_seconds) - float(raw_seconds)
            current_quarter = str(stable.get("game_clock_quarter") or quarter)
            quarter_really_changed = quarter != UNKNOWN and current_quarter != UNKNOWN and quarter != current_quarter

            if quarter_really_changed and raw_seconds > float(last_seconds):
                new_seconds = raw_seconds
                clock_state = "QUARTER_CHANGED"
                stable["same_clock_repeat_count"] = 0
                stable["pending_clock_resync_seconds"] = None
                stable["pending_clock_resync_votes"] = 0

            elif abs(diff) < 0.001:
                # Scoreboard and score are visible, but the clock OCR returned
                # the exact same clock again. This can mean either:
                # 1) real stoppage -> keep clock
                # 2) clock OCR stuck -> recover carefully
                #
                # First use clock ROI motion. If that fails but the visible
                # scoreboard clock has been frozen for too long, use elapsed-time
                # fallback. This fixes sections where score is recognized but
                # clock stays at one value such as 04:44.
                roi_changed = bool(stable.get("clock_roi_changed"))
                roi_motion = float(stable.get("clock_roi_motion") or 0.0)
                same_repeat = int(stable.get("same_clock_repeat_count") or 0) + 1
                stable["same_clock_repeat_count"] = same_repeat

                last_change_time = float(stable.get("last_clock_change_time", time_sec))
                clock_frozen_duration = max(0.0, float(time_sec) - last_change_time)

                if (
                    roi_changed
                    and same_repeat >= VISIBLE_CLOCK_STUCK_REPEAT
                    and CLOCK_ROI_MOTION_MIN_SECONDS <= float(last_seconds) <= CLOCK_ROI_MOTION_MAX_SECONDS
                ):
                    new_seconds = max(0.0, float(last_seconds) - VISIBLE_CLOCK_STUCK_MAX_STEP_SEC)
                    clock_state = (
                        f"VISIBLE_CLOCK_STUCK_RECOVERY"
                        f"(repeat={same_repeat},motion={roi_motion:.2f})"
                    )
                    stable["same_clock_repeat_count"] = 0

                elif (
                    same_repeat >= VISIBLE_CLOCK_STUCK_REPEAT
                    and clock_frozen_duration >= VISIBLE_CLOCK_FORCE_RESYNC_SEC
                    and CLOCK_ROI_MOTION_MIN_SECONDS <= float(last_seconds) <= CLOCK_ROI_MOTION_MAX_SECONDS
                ):
                    correction = min(
                        VISIBLE_CLOCK_FORCE_MAX_STEP_SEC,
                        max(1.0, clock_frozen_duration - VISIBLE_CLOCK_FORCE_RESYNC_SEC + 1.0),
                    )
                    new_seconds = max(0.0, float(last_seconds) - correction)
                    clock_state = (
                        f"VISIBLE_CLOCK_FORCE_RECOVERY"
                        f"(repeat={same_repeat},frozen={clock_frozen_duration:.1f}s,step={correction:.1f})"
                    )
                    stable["same_clock_repeat_count"] = 0

                else:
                    new_seconds = float(last_seconds)
                    clock_state = (
                        f"STOPPED_OBSERVED"
                        f"(repeat={same_repeat},motion={roi_motion:.2f},frozen={clock_frozen_duration:.1f}s)"
                    )

                stable["pending_clock_resync_seconds"] = None
                stable["pending_clock_resync_votes"] = 0
            elif diff < 0:
                # 시간이 증가하는 OCR은 보통 오인식/이전 화면 잔상이다.
                # 단, 쿼터 변경은 위에서 이미 처리했다.
                new_seconds = float(last_seconds)
                clock_state = "HOLD_REJECTED_CLOCK_INCREASE"
                stable["pending_clock_resync_seconds"] = None
                stable["pending_clock_resync_votes"] = 0

            elif raw_seconds <= 1.0:
                # 1초 이하 decimal은 실제 종료 직전 clock일 수 있으므로 보존한다.
                # 01:00 근처에서 갑자기 0.5가 뜨는 노이즈는 diff가 너무 커서 pending으로 보내는 게 안전하다.
                if diff <= MAX_NORMAL_CLOCK_DROP_SEC or float(last_seconds) <= 3.0:
                    new_seconds = raw_seconds
                    clock_state = "OBSERVED_FINAL_DECIMAL"
                    stable["same_clock_repeat_count"] = 0
                    stable["pending_clock_resync_seconds"] = None
                    stable["pending_clock_resync_votes"] = 0
                else:
                    pending = stable.get("pending_clock_resync_seconds")
                    votes = int(stable.get("pending_clock_resync_votes") or 0)
                    if pending == raw_seconds:
                        votes += 1
                    else:
                        pending = raw_seconds
                        votes = 1
                    stable["pending_clock_resync_seconds"] = pending
                    stable["pending_clock_resync_votes"] = votes
                    if votes >= PENDING_CLOCK_RESYNC_COUNT:
                        new_seconds = raw_seconds
                        clock_state = "OBSERVED_FINAL_DECIMAL_RESYNC"
                        stable["pending_clock_resync_seconds"] = None
                        stable["pending_clock_resync_votes"] = 0
                    else:
                        new_seconds = float(last_seconds)
                        clock_state = "PENDING_FINAL_DECIMAL_HOLD"

            elif 0 < diff <= MAX_NORMAL_CLOCK_DROP_SEC:
                new_seconds = raw_seconds
                clock_state = "OBSERVED_DECREASE"
                stable["same_clock_repeat_count"] = 0
                stable["pending_clock_resync_seconds"] = None
                stable["pending_clock_resync_votes"] = 0

            elif float(last_seconds) <= 65.0 and raw_seconds <= 59.0 and 0 < diff <= 20.0:
                # TNT 1분 미만 decimal이 초 단위로 변환되어 들어온 경우.
                # 예: OCR raw 50.2 -> 00:50. 다만 예측 감소는 하지 않고, 읽힌 값만 반영한다.
                pending = stable.get("pending_clock_resync_seconds")
                votes = int(stable.get("pending_clock_resync_votes") or 0)
                if pending == raw_seconds:
                    votes += 1
                else:
                    pending = raw_seconds
                    votes = 1
                stable["pending_clock_resync_seconds"] = pending
                stable["pending_clock_resync_votes"] = votes

                # subminute 큰 점프는 2번만 반복돼도 허용. 00:45 같은 노이즈 1회 반영 방지용.
                if votes >= 2:
                    new_seconds = raw_seconds
                    clock_state = "OBSERVED_SUBMINUTE_RESYNC"
                    stable["pending_clock_resync_seconds"] = None
                    stable["pending_clock_resync_votes"] = 0
                else:
                    new_seconds = float(last_seconds)
                    clock_state = "PENDING_SUBMINUTE_HOLD"

            elif 0 < diff <= MAX_CUT_CLOCK_RESYNC_DROP_SEC:
                # If the scoreboard just reappeared after missing frames,
                # a larger clock drop can be real because the clock kept running
                # while score/scoreboard OCR was unavailable.
                previous_missing_count = int(stable.get("scoreboard_missing_count_before_reappear") or 0)
                reappear_allow_drop = max(
                    float(MAX_NORMAL_CLOCK_DROP_SEC),
                    float(previous_missing_count) + REAPPEAR_CLOCK_RESYNC_BUFFER_SEC,
                )

                if previous_missing_count >= MISSING_CONFIRM_COUNT and diff <= reappear_allow_drop:
                    new_seconds = raw_seconds
                    clock_state = (
                        f"OBSERVED_REAPPEAR_DROP"
                        f"(drop={diff:.2f},missing={previous_missing_count},limit={reappear_allow_drop:.1f})"
                    )
                    stable["same_clock_repeat_count"] = 0
                    stable["pending_clock_resync_seconds"] = None
                    stable["pending_clock_resync_votes"] = 0

                else:
                    # Big visible-scoreboard drop is dangerous in normal play.
                    # Allow it only if the clock has been stuck for a while.
                    # This protects early sections that were already working,
                    # but still fixes long 04:44-style lockups later.
                    last_change_time = float(stable.get("last_clock_change_time", time_sec))
                    clock_stuck_duration = max(0.0, float(time_sec) - last_change_time)

                    if clock_stuck_duration < BIG_DROP_RESYNC_STUCK_SEC:
                        new_seconds = float(last_seconds)
                        clock_state = (
                            f"PENDING_BIG_DROP_HOLD_NOT_STUCK"
                            f"(drop={diff:.2f},stuck={clock_stuck_duration:.1f}s,missing={previous_missing_count})"
                        )
                        stable["pending_clock_resync_seconds"] = None
                        stable["pending_clock_resync_votes"] = 0
                    else:
                        pending = stable.get("pending_clock_resync_seconds")
                        votes = int(stable.get("pending_clock_resync_votes") or 0)
                        if pending == raw_seconds:
                            votes += 1
                        else:
                            pending = raw_seconds
                            votes = 1

                        stable["pending_clock_resync_seconds"] = pending
                        stable["pending_clock_resync_votes"] = votes

                        if votes >= PENDING_CLOCK_RESYNC_COUNT:
                            new_seconds = raw_seconds
                            clock_state = (
                                f"OBSERVED_BIG_DROP_RESYNC_AFTER_STUCK"
                                f"(drop={diff:.2f},stuck={clock_stuck_duration:.1f}s)"
                            )
                            stable["pending_clock_resync_seconds"] = None
                            stable["pending_clock_resync_votes"] = 0
                        else:
                            new_seconds = float(last_seconds)
                            clock_state = (
                                f"PENDING_BIG_DROP_HOLD_AFTER_STUCK"
                                f"(votes={votes},drop={diff:.2f},stuck={clock_stuck_duration:.1f}s)"
                            )

            else:
                new_seconds = float(last_seconds)
                clock_state = "HOLD_REJECTED_CLOCK"
    else:
        new_seconds = None
        clock_state = "UNKNOWN"

    previous_stable_seconds_for_update = stable.get("game_clock_seconds")

    if isinstance(new_seconds, (int, float)):
        # raw_clock이 1초 이하 decimal이면 0.05 같은 표시를 그대로 우선 사용한다.
        if (
            raw_seconds is not None
            and float(raw_seconds) <= 1.0
            and abs(float(new_seconds) - float(raw_seconds)) < 1e-9
            and re.fullmatch(r"[01]\.\d{1,2}", str(raw_clock).strip())
        ):
            game_clock = str(raw_clock).strip()
        else:
            game_clock = seconds_to_game_clock(new_seconds)

        stable["game_clock"] = game_clock
        stable["game_clock_seconds"] = new_seconds

        if isinstance(previous_stable_seconds_for_update, (int, float)):
            if abs(float(new_seconds) - float(previous_stable_seconds_for_update)) > 0.001:
                stable["last_clock_change_time"] = time_sec
        elif "last_clock_change_time" not in stable:
            stable["last_clock_change_time"] = time_sec

        stable["game_clock_time"] = time_sec
        stable["game_clock_quarter"] = quarter
        stable["clock_state"] = clock_state
    else:
        game_clock = str(stable.get("game_clock") or UNKNOWN)

    stable["scoreboard_just_reappeared"] = False
    stable["scoreboard_missing_count_before_reappear"] = 0

    return ParsedScoreboard(
        team1_score=parsed.team1_score,
        team2_score=parsed.team2_score,
        team1_name=team1,
        team2_name=team2,
        quarter=quarter,
        game_clock=game_clock,
        region_score=parsed.region_score,
    )

def apply_long_missing_clock_resync_if_needed(
    parsed: ParsedScoreboard,
    stable: dict[str, object],
    previous_missing_count: int,
    time_sec: float,
) -> tuple[ParsedScoreboard | None, bool]:
    """Handle long consecutive confirmed missing sections.

    Important:
    - previous_missing_count includes candidate missing samples too.
    - Therefore we convert it to confirmed_missing_count.
    - Only when confirmed missing is consecutive 10+ do we treat it as a cut/edit section.
    - Even then, clock is not blindly adjusted by -5s.
      It is resynced only if OCR observes a lower clock within MAX_CLOCK_RESYNC_DROP_SEC.
    """
    confirmed_missing_count = max(0, previous_missing_count - MISSING_CONFIRM_COUNT + 1)

    if confirmed_missing_count < CUT_EDIT_MISSING_COUNT:
        return parsed, False

    last_seconds = stable.get("game_clock_seconds")
    raw_seconds = clock_display_to_seconds_float(parsed.game_clock) if parsed.game_clock else None

    print(
        "           -> long confirmed missing detected: "
        f"{confirmed_missing_count} confirmed missing samples "
        f"(total missing={previous_missing_count}), OCR clock resync mode"
    )

    if not isinstance(last_seconds, (int, float)):
        return parsed, False

    old_clock = seconds_to_game_clock(int(last_seconds))
    resync_drop = last_seconds - raw_seconds if raw_seconds is not None else None

    if (
        raw_seconds is not None
        and raw_seconds < last_seconds
        and 0 < resync_drop <= MAX_CUT_CLOCK_RESYNC_DROP_SEC
    ):
        new_seconds = raw_seconds
        new_clock = decimal_seconds_to_display(float(new_seconds), parsed.game_clock) if float(new_seconds) <= 1.0 and parsed.game_clock else seconds_to_game_clock(int(new_seconds))
        print(
            "           -> clock resynced after long confirmed missing: "
            f"{old_clock} -> {new_clock} "
            f"(drop={resync_drop}s, limit={MAX_CUT_CLOCK_RESYNC_DROP_SEC}s)"
        )
    else:
        new_seconds = last_seconds
        new_clock = old_clock
        print(
            "           -> rejected long-missing clock OCR, keep previous clock: "
            f"last={old_clock}, "
            f"raw={seconds_to_game_clock(int(raw_seconds)) if raw_seconds is not None else UNKNOWN}, "
            f"limit={MAX_CUT_CLOCK_RESYNC_DROP_SEC}s"
        )

    raw_quarter = parsed.quarter or ""
    quarter = normalize_stable_quarter(stable, raw_quarter, new_seconds)

    team1 = str(stable.get("team1_name") or parsed.team1_name or UNKNOWN)
    team2 = str(stable.get("team2_name") or parsed.team2_name or UNKNOWN)
    if team1 == UNKNOWN and parsed.team1_name:
        team1 = parsed.team1_name
    if team2 == UNKNOWN and parsed.team2_name:
        team2 = parsed.team2_name
    if team1 != UNKNOWN:
        stable["team1_name"] = team1
    if team2 != UNKNOWN:
        stable["team2_name"] = team2

    previous_long_missing_seconds_for_update = stable.get("game_clock_seconds")

    stable["game_clock"] = new_clock
    stable["game_clock_seconds"] = new_seconds

    if isinstance(previous_long_missing_seconds_for_update, (int, float)):
        if abs(float(new_seconds) - float(previous_long_missing_seconds_for_update)) > 0.001:
            stable["last_clock_change_time"] = time_sec
    elif "last_clock_change_time" not in stable:
        stable["last_clock_change_time"] = time_sec

    stable["game_clock_time"] = time_sec
    stable["game_clock_quarter"] = quarter
    stable["clock_state"] = "OBSERVED_RESYNC" if new_seconds != last_seconds else "HOLD_AFTER_LONG_MISSING"
    stable["force_clock_resync"] = False
    stable["scoreboard_missing_count"] = 0
    stable["scoreboard_missing_confirmed"] = False
    stable["scoreboard_just_reappeared"] = False
    stable["scoreboard_missing_count_before_reappear"] = 0

    return (
        ParsedScoreboard(
            team1_score=parsed.team1_score,
            team2_score=parsed.team2_score,
            team1_name=team1,
            team2_name=team2,
            quarter=quarter,
            game_clock=new_clock,
            region_score=parsed.region_score,
        ),
        True,
    )

def append_record(records: list[dict[str, object]], time_sec: float, parsed: ParsedScoreboard) -> None:
    records.append(
        {
            "analysis_time": format_analysis_time(time_sec),
            "team1": parsed.team1_name,
            "team2": parsed.team2_name,
            "team1_score": parsed.team1_score,
            "team2_score": parsed.team2_score,
            "quarter": parsed.quarter,
            "game_clock": parsed.game_clock,
        }
    )


def print_scoreboard(time_sec: float, parsed: ParsedScoreboard) -> None:
    print(
        f"[{format_analysis_time(time_sec)}] "
        f"{parsed.team1_name} : {parsed.team2_name} | "
        f"{parsed.team1_score} : {parsed.team2_score} | "
        f"{parsed.quarter} | {parsed.game_clock}"
    )


def print_score_change_summary(df: pd.DataFrame) -> None:
    print("\n=== Score changes ===")

    if df.empty:
        print("No confirmed score changes.")
        print("Final score: UNKNOWN")
        return

    previous_score: tuple[int, int] | None = None
    final_row = df.iloc[0]
    shown_count = 0

    for _, row in df.iterrows():
        score = (int(row["team1_score"]), int(row["team2_score"]))
        if previous_score is None:
            previous_score = score
            final_row = row
            continue

        if score == previous_score:
            final_row = row
            continue

        if not is_valid_score_transition(score, previous_score):
            continue

        previous_score = score
        final_row = row
        shown_count += 1
        print(
            f"[{row['analysis_time']}] "
            f"{row['team1']} : {row['team2']} | "
            f"{row['team1_score']} : {row['team2_score']} | "
            f"{row['quarter']} | {row['game_clock']}"
        )

    if shown_count == 0:
        print("No confirmed score changes.")

    print(
        "\nFinal score: "
        f"{final_row['team1']} {final_row['team1_score']} : "
        f"{final_row['team2_score']} {final_row['team2']}"
    )


def analyze_video(
    reader: easyocr.Reader,
    video_path: str = DEFAULT_VIDEO_PATH,
    output_path: str = DEFAULT_OUTPUT_PATH,
    team1_name: str = UNKNOWN,
    team2_name: str = UNKNOWN,
    manual_score_boxes: tuple[tuple[float, float, float, float], tuple[float, float, float, float]] | None = None,
    interval_sec: float = DEFAULT_INTERVAL_SEC,
    confirm_count: int = DEFAULT_CONFIRM_COUNT,
    resync_count: int = DEFAULT_RESYNC_COUNT,
    record_mode: str = "score-change",
    debug: bool = False,
    max_samples: int = 0,
    start_sec: float | None = None,
    end_sec: float | None = None,
) -> pd.DataFrame:
    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        raise FileNotFoundError(f"Could not open video: {video_path}")

    fps = cap.get(cv2.CAP_PROP_FPS)
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    if not fps or fps <= 0:
        fps = 30.0

    frame_step = max(1, int(round(fps * interval_sec)))

    print(f"Video: {video_path}")
    print(f"FPS: {fps:.2f}, frames: {total_frames}, OCR every {frame_step} frames")

    records: list[dict[str, object]] = []
    stable: dict[str, object] = {
        "team1_name": "" if team1_name.strip().upper() == UNKNOWN else team1_name.strip().upper(),
        "team2_name": "" if team2_name.strip().upper() == UNKNOWN else team2_name.strip().upper(),
    }
    last_confirmed_score: tuple[int, int] | None = None
    initial_score_counts: Counter[tuple[int, int]] = Counter()
    initial_score_samples: dict[tuple[int, int], tuple[float, ParsedScoreboard, str]] = {}
    pending_corrected_score: tuple[int, int] | None = None
    pending_corrected_time: float = 0.0
    pending_corrected_parsed: ParsedScoreboard | None = None
    pending_corrected_votes = 0

    # 모든 정상 점수 변화(+1, +2, +3)는 바로 확정하지 않는다.
    # 같은 점수가 연속으로 confirm_count번 읽힐 때만 확정한다.
    pending_valid_score: tuple[int, int] | None = None
    pending_valid_time: float = 0.0
    pending_valid_parsed: ParsedScoreboard | None = None
    pending_valid_votes = 0

    pending_resync_score: tuple[int, int] | None = None
    pending_resync_time: float = 0.0
    pending_resync_parsed: ParsedScoreboard | None = None
    pending_resync_votes = 0
    processed_samples = 0

    # start_sec가 있으면 영상 앞부분을 전부 읽으며 스킵하지 않고
    # OpenCV가 바로 해당 시간대 프레임으로 이동하게 한다.
    if start_sec is not None:
        frame_id = max(0, int(round(start_sec * fps)))
        cap.set(cv2.CAP_PROP_POS_FRAMES, frame_id)
    else:
        frame_id = 0

    while True:
        ret, frame = cap.read()
        if not ret:
            break

        if frame_id % frame_step != 0:
            frame_id += 1
            continue

        time_sec = frame_id / fps

        # ===== DEBUG TIME RANGE =====
        # Only analyze a selected part of the video.
        # Default in the bottom call: 04:35 ~ 05:35.
        if start_sec is not None and time_sec < start_sec:
            frame_id += 1
            continue
        if end_sec is not None and time_sec > end_sec:
            break
        # ============================

        processed_samples += 1

        if max_samples and processed_samples > max_samples:
            break

        result = choose_best_region(
            reader,
            frame,
            debug=debug,
            manual_score_boxes=manual_score_boxes,
            known_team_names=(
                str(stable.get("team1_name") or ""),
                str(stable.get("team2_name") or ""),
            ),
        )
        if result is None:
            missing_clock = handle_scoreboard_missing(stable, time_sec, reader=reader, frame=frame)
            missing_count = int(stable.get("scoreboard_missing_count") or 0)
            if missing_count < MISSING_CONFIRM_COUNT:
                print(
                    f"[{format_analysis_time(time_sec)}] scoreboard not found "
                    f"(candidate {missing_count}/{MISSING_CONFIRM_COUNT}) | clock {missing_clock}"
                )
            else:
                print(
                    f"[{format_analysis_time(time_sec)}] scoreboard not found "
                    f"(confirmed) | clock {missing_clock}"
                )
            frame_id += 1
            continue

        region_name, parsed = result

        # Reject non-scoreboard graphics before applying stable context.
        # This keeps ads/lower-thirds like AUDIO ASSIST from inheriting old team names
        # and being treated as a real scoreboard.
        if not is_valid_scoreboard_candidate(parsed, last_confirmed_score):
            missing_clock = handle_scoreboard_missing(stable, time_sec, reader=reader, frame=frame)
            missing_count = int(stable.get("scoreboard_missing_count") or 0)
            if debug:
                print(
                    "           -> rejected non-scoreboard candidate: "
                    f"{parsed.team1_score}:{parsed.team2_score}, "
                    f"quarter={parsed.quarter or UNKNOWN}, clock={parsed.game_clock or UNKNOWN}, "
                    f"region={region_name}"
                )
            if missing_count < MISSING_CONFIRM_COUNT:
                print(
                    f"[{format_analysis_time(time_sec)}] scoreboard not found "
                    f"(candidate {missing_count}/{MISSING_CONFIRM_COUNT}) | clock {missing_clock}"
                )
            else:
                print(
                    f"[{format_analysis_time(time_sec)}] scoreboard not found "
                    f"(confirmed) | clock {missing_clock}"
                )
            frame_id += 1
            continue

        previous_missing_count = int(stable.get("scoreboard_missing_count") or 0)

        # Clock OCR이 같은 숫자를 반복할 때, 실제 정지인지 OCR stuck인지 구분하기 위한
        # clock 전용 crop 변화량을 저장한다. 정상 OCR 감소 구간에는 영향을 주지 않는다.
        update_clock_roi_motion_state(stable, frame)

        if previous_missing_count > 0:
            stable["scoreboard_just_reappeared"] = True
            stable["scoreboard_missing_count_before_reappear"] = previous_missing_count

            # 10번 이상 missing이면 컷편집으로 보고, 여기서 먼저 clock 재동기화를 시도한다.
            # 재동기화가 성공하면 old clock을 출력하지 않고 바로 새 clock으로 출력한다.
            # 재동기화가 실패하면 이번 프레임은 버리고 다음 scoreboard 프레임을 기다린다.
            resynced_parsed, handled_long_missing = apply_long_missing_clock_resync_if_needed(
                parsed,
                stable,
                previous_missing_count,
                time_sec,
            )
            if handled_long_missing:
                if resynced_parsed is None:
                    frame_id += 1
                    continue
                parsed = resynced_parsed
            else:
                stable["scoreboard_missing_count"] = 0
                stable["scoreboard_missing_confirmed"] = False
                parsed = apply_stable_context(parsed, stable, time_sec)
        else:
            stable["scoreboard_just_reappeared"] = False
            stable["scoreboard_missing_count_before_reappear"] = 0
            parsed = apply_stable_context(parsed, stable, time_sec)

        score = parsed.score

        print_scoreboard(time_sec, parsed)

        if last_confirmed_score is None:
            if time_sec < INITIAL_SCORE_WINDOW_SEC:
                initial_score_counts[score] += 1
                initial_score_samples[score] = (time_sec, parsed, region_name)
                print(
                    "           -> initial candidate collected: "
                    f"{score[0]}:{score[1]} ({initial_score_counts[score]} votes, not confirmed)"
                )
                frame_id += 1
                continue

            if initial_score_counts:
                initial_score, votes = initial_score_counts.most_common(1)[0]
                sample_time, sample_parsed, sample_region = initial_score_samples[initial_score]
                last_confirmed_score = initial_score
                append_record(records, sample_time, sample_parsed)
                print(
                    "           -> initial score confirmed by majority: "
                    f"{initial_score[0]}:{initial_score[1]} ({votes} votes, {sample_region})"
                )

                if score == last_confirmed_score:
                    frame_id += 1
                    continue
            else:
                last_confirmed_score = score
                append_record(records, time_sec, parsed)
                print(f"           -> initial score confirmed from {region_name}")
                frame_id += 1
                continue

        if not is_valid_score_transition(score, last_confirmed_score):
            corrected_score = infer_plausible_score_from_ocr_error(score, last_confirmed_score)
            if corrected_score is not None:
                corrected_parsed = with_score(parsed, corrected_score)
                if pending_corrected_score == corrected_score:
                    pending_corrected_votes += 1
                else:
                    pending_corrected_score = corrected_score
                    pending_corrected_time = time_sec
                    pending_corrected_parsed = corrected_parsed
                    pending_corrected_votes = 1

                print(
                    "           -> possible OCR score correction: "
                    f"{score[0]}:{score[1]} -> {corrected_score[0]}:{corrected_score[1]} "
                    f"({pending_corrected_votes} votes)"
                )

                if pending_corrected_votes >= max(1, confirm_count):
                    last_confirmed_score = corrected_score
                    append_record(records, pending_corrected_time, pending_corrected_parsed or corrected_parsed)
                    print(
                        "           -> corrected score change recorded: "
                        f"{corrected_score[0]}:{corrected_score[1]} "
                        f"at {format_analysis_time(pending_corrected_time)}"
                    )
                    pending_corrected_score = None
                    pending_corrected_parsed = None
                    pending_corrected_votes = 0
                    pending_valid_score = None
                    pending_valid_parsed = None
                    pending_valid_votes = 0
                    pending_resync_score = None
                    pending_resync_parsed = None
                    pending_resync_votes = 0

                frame_id += 1
                continue

            if is_plausible_resync_score(score, last_confirmed_score):
                if pending_resync_score == score:
                    pending_resync_votes += 1
                else:
                    pending_resync_score = score
                    pending_resync_time = time_sec
                    pending_resync_parsed = parsed
                    pending_resync_votes = 1

                print(
                    "           -> possible score resync: "
                    f"{last_confirmed_score[0]}:{last_confirmed_score[1]} -> {score[0]}:{score[1]} "
                    f"({pending_resync_votes} votes)"
                )

                if pending_resync_votes >= max(1, resync_count):
                    last_confirmed_score = score
                    append_record(records, pending_resync_time, pending_resync_parsed or parsed)
                    print(
                        "           -> score resynced after repeated read: "
                        f"{score[0]}:{score[1]} at {format_analysis_time(pending_resync_time)}"
                    )
                    pending_resync_score = None
                    pending_resync_parsed = None
                    pending_resync_votes = 0

                frame_id += 1
                continue

            pending_resync_score = None
            pending_resync_parsed = None
            pending_resync_votes = 0
            pending_valid_score = None
            pending_valid_parsed = None
            pending_valid_votes = 0

            print(
                "           -> ignored invalid score transition: "
                f"{last_confirmed_score[0]}:{last_confirmed_score[1]} -> {score[0]}:{score[1]}"
            )
            frame_id += 1
            continue

        if score != last_confirmed_score:
            # 이전에 OCR 보정으로 후보가 잡혔고, 이번 프레임에서 같은 점수가 실제로 읽히면
            # 보정 후보 1회 + 실제 후보 1회로 보고 확정한다.
            if pending_corrected_score == score and pending_corrected_parsed is not None:
                last_confirmed_score = score
                append_record(records, pending_corrected_time, pending_corrected_parsed)
                print(
                    "           -> score change confirmed from earlier OCR correction: "
                    f"{score[0]}:{score[1]} at {format_analysis_time(pending_corrected_time)}"
                )
                pending_corrected_score = None
                pending_corrected_parsed = None
                pending_corrected_votes = 0
                pending_valid_score = None
                pending_valid_parsed = None
                pending_valid_votes = 0
                pending_resync_score = None
                pending_resync_parsed = None
                pending_resync_votes = 0
                frame_id += 1
                continue

            # +1, +2, +3 모두 여기서 바로 확정하지 않고 후보로만 둔다.
            # 같은 후보 점수가 연속으로 confirm_count번 읽힌 경우에만 확정한다.
            if pending_valid_score == score:
                pending_valid_votes += 1
            else:
                pending_valid_score = score
                pending_valid_time = time_sec
                pending_valid_parsed = parsed
                pending_valid_votes = 1

            print(
                "           -> possible valid score change: "
                f"{last_confirmed_score[0]}:{last_confirmed_score[1]} -> "
                f"{score[0]}:{score[1]} ({pending_valid_votes}/{max(1, confirm_count)} votes)"
            )

            if pending_valid_votes >= max(1, confirm_count):
                last_confirmed_score = score
                append_record(records, pending_valid_time, pending_valid_parsed or parsed)
                print(
                    "           -> score change confirmed: "
                    f"{score[0]}:{score[1]} at {format_analysis_time(pending_valid_time)}"
                )
                pending_valid_score = None
                pending_valid_parsed = None
                pending_valid_votes = 0
                pending_corrected_score = None
                pending_corrected_parsed = None
                pending_corrected_votes = 0
                pending_resync_score = None
                pending_resync_parsed = None
                pending_resync_votes = 0
        else:
            # 다시 확정 점수가 읽히면 직전 점수 변화 후보는 취소한다.
            pending_valid_score = None
            pending_valid_parsed = None
            pending_valid_votes = 0
            if record_mode == "every-sample":
                append_record(records, time_sec, parsed)

        frame_id += 1

    cap.release()

    columns = [
        "analysis_time",
        "team1",
        "team2",
        "team1_score",
        "team2_score",
        "quarter",
        "game_clock",
    ]
    df = pd.DataFrame(records, columns=columns)
    df.to_csv(output_path, index=False, encoding="utf-8-sig")
    print(f"Saved: {output_path}")
    print_score_change_summary(df)
    return df


def main() -> None:
    args = parse_args()
    left_score_box = parse_box_arg(args.left_score_box)
    right_score_box = parse_box_arg(args.right_score_box)
    manual_score_boxes = None
    if left_score_box or right_score_box:
        if left_score_box is None or right_score_box is None:
            raise ValueError("--left-score-box and --right-score-box must be used together")
        manual_score_boxes = (left_score_box, right_score_box)

    print("Preparing EasyOCR model...")
    reader = easyocr.Reader(["en"], gpu=args.gpu)

    analyze_video(
        reader=reader,
        video_path=str(Path(args.video)),
        output_path=str(Path(args.output)),
        team1_name=args.team1,
        team2_name=args.team2,
        manual_score_boxes=manual_score_boxes,
        interval_sec=args.interval,
        confirm_count=max(1, args.confirm_count),
        resync_count=max(1, args.resync_count),
        record_mode=args.record_mode,
        debug=args.debug,
        max_samples=args.max_samples,
        start_sec=args.start_sec,
        end_sec=args.end_sec,
    )


print("Preparing EasyOCR model...")
print("FULL RUN MODE v7: visible scoreboard clock freeze recovery")

reader = easyocr.Reader(["en"], gpu=True)

analyze_video(
    reader=reader,
    video_path=DEFAULT_VIDEO_PATH,
    output_path="/kaggle/working/score_timeline_full_conservative_plus_decimal_v7_visible_clock_fix.csv",
    interval_sec=1.0,
    debug=False,
    max_samples=0,
    start_sec=None,
    end_sec=None,
)
# Out:
# Preparing EasyOCR model...
# FULL RUN MODE v7: visible scoreboard clock freeze recovery
# Video: /kaggle/input/datasets/yerinim/basketball/1_.mp4
# FPS: 30.00, frames: 46800, OCR every 30 frames
# [00:00:00] DEN : UTA | 45 : 43 | 2Q | 07:41
#            -> initial candidate collected: 45:43 (1 votes, not confirmed)
# [00:00:01] DEN : UTA | 45 : 43 | 2Q | 07:41
#            -> initial candidate collected: 45:43 (2 votes, not confirmed)
# [00:00:02] DEN : UTA | 45 : 43 | 2Q | 07:41
#            -> initial candidate collected: 45:43 (3 votes, not confirmed)
# [00:00:03] DEN : UTA | 45 : 43 | 2Q | 07:41
#            -> initial candidate collected: 45:43 (4 votes, not confirmed)
# [00:00:04] DEN : UTA | 45 : 43 | 2Q | 07:41
#            -> initial candidate collected: 45:43 (5 votes, not confirmed)
# [00:00:05] DEN : UTA | 45 : 43 | 2Q | 07:41
#            -> initial score confirmed by majority: 45:43 (5 votes, tnt_bottom_right)
# [00:00:06] DEN : UTA | 45 : 43 | 2Q | 07:41
# [00:00:07] DEN : UTA | 45 : 43 | 2Q | 07:41
# [00:00:08] DEN : UTA | 45 : 43 | 2Q | 07:40
# [00:00:09] DEN : UTA | 45 : 43 | 2Q | 07:39
# [00:00:10] DEN : UTA | 45 : 43 | 2Q | 07:38
# [00:00:11] DEN : UTA | 45 : 43 | 2Q | 07:37
# [00:00:12] DEN : UTA | 45 : 43 | 2Q | 07:36
# [00:00:13] DEN : UTA | 45 : 43 | 2Q | 07:35
# [00:00:14] DEN : UTA | 45 : 43 | 2Q | 07:34
# [00:00:15] DEN : UTA | 45 : 43 | 2Q | 07:33
# [00:00:16] DEN : UTA | 45 : 43 | 2Q | 07:32
# [00:00:17] DEN : UTA | 45 : 43 | 2Q | 07:31
# [00:00:18] DEN : UTA | 45 : 43 | 2Q | 07:30
# [00:00:19] scoreboard not found (candidate 1/3) | clock 07:30
# [00:00:20] DEN : UTA | 45 : 43 | 2Q | 07:28
# [00:00:21] DEN : UTA | 45 : 43 | 2Q | 07:27
# [00:00:22] DEN : UTA | 45 : 43 | 2Q | 07:26
# [00:00:23] DEN : UTA | 45 : 43 | 2Q | 07:25
# [00:00:24] DEN : UTA | 45 : 43 | 2Q | 07:24
# [00:00:25] DEN : UTA | 45 : 43 | 2Q | 07:23
# [00:00:26] DEN : UTA | 45 : 43 | 2Q | 07:22
# [00:00:27] DEN : UTA | 45 : 43 | 2Q | 07:21
# [00:00:28] DEN : UTA | 45 : 43 | 2Q | 07:20
# [00:00:29] DEN : UTA | 45 : 43 | 2Q | 07:19
# [00:00:30] scoreboard not found (candidate 1/3) | clock 07:19
# [00:00:31] DEN : UTA | 45 : 43 | 2Q | 07:17
# [00:00:32] scoreboard not found (candidate 1/3) | clock 07:17
# [00:00:33] scoreboard not found (candidate 2/3) | clock 07:17
# [00:00:34] DEN : UTA | 45 : 43 | 2Q | 07:16
# [00:00:35] scoreboard not found (candidate 1/3) | clock 07:16
# [00:00:36] scoreboard not found (candidate 2/3) | clock 07:16
# [00:00:37] scoreboard not found (confirmed) | clock 07:16
# [00:00:38] scoreboard not found (confirmed) | clock 07:16
# [00:00:39] scoreboard not found (confirmed) | clock 07:16
# [00:00:40] scoreboard not found (confirmed) | clock 07:16
# [00:00:41] scoreboard not found (confirmed) | clock 07:16
# [00:00:42] scoreboard not found (confirmed) | clock 07:16
# [00:00:43] scoreboard not found (confirmed) | clock 07:16
# [00:00:44] scoreboard not found (confirmed) | clock 07:16
# [00:00:45] scoreboard not found (confirmed) | clock 07:16
# [00:00:46] DEN : UTA | 45 : 43 | 2Q | 07:02
# [00:00:47] DEN : UTA | 45 : 43 | 2Q | 07:01
# [00:00:48] DEN : UTA | 45 : 43 | 2Q | 07:00
# [00:00:49] DEN : UTA | 45 : 43 | 2Q | 06:59
# [00:00:50] DEN : UTA | 45 : 43 | 2Q | 06:58
# [00:00:51] DEN : UTA | 45 : 43 | 2Q | 06:57
# [00:00:52] DEN : UTA | 45 : 43 | 2Q | 06:56
# [00:00:53] DEN : UTA | 45 : 43 | 2Q | 06:55
# [00:00:54] DEN : UTA | 45 : 43 | 2Q | 06:54
# [00:00:55] scoreboard not found (candidate 1/3) | clock 06:54
# [00:00:56] scoreboard not found (candidate 2/3) | clock 06:54
# [00:00:57] scoreboard not found (confirmed) | clock 06:54
# [00:00:58] scoreboard not found (confirmed) | clock 06:54
# [00:00:59] DEN : UTA | 46 : 43 | 2Q | 06:49
#            -> possible valid score change: 45:43 -> 46:43 (1/2 votes)
# [00:01:00] DEN : UTA | 46 : 43 | 2Q | 06:48
#            -> possible valid score change: 45:43 -> 46:43 (2/2 votes)
#            -> score change confirmed: 46:43 at 00:00:59
# [00:01:01] DEN : UTA | 46 : 43 | 2Q | 06:48
# [00:01:02] DEN : UTA | 46 : 43 | 2Q | 06:46
# [00:01:03] DEN : UTA | 46 : 43 | 2Q | 06:45
# [00:01:04] DEN : UTA | 48 : 43 | 2Q | 06:44
#            -> possible valid score change: 46:43 -> 48:43 (1/2 votes)
# [00:01:05] DEN : UTA | 48 : 43 | 2Q | 06:43
#            -> possible valid score change: 46:43 -> 48:43 (2/2 votes)
#            -> score change confirmed: 48:43 at 00:01:04
# [00:01:06] DEN : UTA | 48 : 43 | 2Q | 06:42
# [00:01:07] DEN : UTA | 48 : 43 | 2Q | 06:41
# [00:01:08] DEN : UTA | 48 : 43 | 2Q | 06:40
# [00:01:09] DEN : UTA | 48 : 43 | 2Q | 06:39
# [00:01:10] DEN : UTA | 48 : 43 | 2Q | 06:38
# [00:01:11] DEN : UTA | 48 : 43 | 2Q | 06:37
# [00:01:12] DEN : UTA | 48 : 43 | 2Q | 06:36
# [00:01:13] DEN : UTA | 48 : 43 | 2Q | 06:35
# [00:01:14] DEN : UTA | 48 : 43 | 2Q | 06:34
# [00:01:15] DEN : UTA | 48 : 43 | 2Q | 06:33
# [00:01:16] scoreboard not found (candidate 1/3) | clock 06:33
# [00:01:17] DEN : UTA | 48 : 45 | 2Q | 06:31
#            -> possible valid score change: 48:43 -> 48:45 (1/2 votes)
# [00:01:18] DEN : UTA | 48 : 45 | 2Q | 06:30
#            -> possible valid score change: 48:43 -> 48:45 (2/2 votes)
#            -> score change confirmed: 48:45 at 00:01:17
# [00:01:19] DEN : UTA | 48 : 45 | 2Q | 06:29
# [00:01:20] DEN : UTA | 48 : 45 | 2Q | 06:28
# [00:01:21] DEN : UTA | 48 : 45 | 2Q | 06:27
# [00:01:22] DEN : UTA | 48 : 45 | 2Q | 06:26
# [00:01:23] DEN : UTA | 48 : 45 | 2Q | 06:25
# [00:01:24] DEN : UTA | 48 : 45 | 2Q | 06:24
# [00:01:25] DEN : UTA | 48 : 45 | 2Q | 06:23
# [00:01:26] DEN : UTA | 48 : 45 | 2Q | 06:22
# [00:01:27] scoreboard not found (candidate 1/3) | clock 06:22
# [00:01:28] scoreboard not found (candidate 2/3) | clock 06:22
# [00:01:29] DEN : UTA | 48 : 45 | 2Q | 06:19
# [00:01:30] DEN : UTA | 48 : 45 | 2Q | 06:18
# [00:01:31] DEN : UTA | 48 : 45 | 2Q | 06:17
# [00:01:32] DEN : UTA | 48 : 45 | 2Q | 06:16
# [00:01:33] DEN : UTA | 48 : 45 | 2Q | 06:15
# [00:01:34] DEN : UTA | 50 : 45 | 2Q | 06:14
#            -> possible valid score change: 48:45 -> 50:45 (1/2 votes)
# [00:01:35] DEN : UTA | 50 : 45 | 2Q | 06:13
#            -> possible valid score change: 48:45 -> 50:45 (2/2 votes)
#            -> score change confirmed: 50:45 at 00:01:34
# [00:01:36] DEN : UTA | 50 : 45 | 2Q | 06:12
# [00:01:37] DEN : UTA | 50 : 45 | 2Q | 06:11
# [00:01:38] DEN : UTA | 50 : 45 | 2Q | 06:10
# [00:01:39] DEN : UTA | 50 : 45 | 2Q | 06:09
# [00:01:40] DEN : UTA | 50 : 45 | 2Q | 06:08
# [00:01:41] DEN : UTA | 50 : 45 | 2Q | 06:07
# [00:01:42] DEN : UTA | 50 : 45 | 2Q | 06:06
# [00:01:43] DEN : UTA | 50 : 45 | 2Q | 06:05
# [00:01:44] DEN : UTA | 50 : 45 | 2Q | 06:04
# [00:01:45] DEN : UTA | 50 : 45 | 2Q | 06:03
# [00:01:46] DEN : UTA | 50 : 45 | 2Q | 06:02
# [00:01:47] DEN : UTA | 50 : 45 | 2Q | 06:01
# [00:01:48] scoreboard not found (candidate 1/3) | clock 06:01
# [00:01:49] DEN : UTA | 50 : 45 | 2Q | 05:59
# [00:01:50] DEN : UTA | 50 : 45 | 2Q | 05:59
# [00:01:51] scoreboard not found (candidate 1/3) | clock 05:59
# [00:01:52] scoreboard not found (candidate 2/3) | clock 05:59
# [00:01:53] scoreboard not found (confirmed) | clock 05:59
# [00:01:54] scoreboard not found (confirmed) | clock 05:59
# [00:01:55] scoreboard not found (confirmed) | clock 05:59
# [00:01:56] scoreboard not found (confirmed) | clock 05:59
# [00:01:57] scoreboard not found (confirmed) | clock 05:59
# [00:01:58] scoreboard not found (confirmed) | clock 05:59
# [00:01:59] scoreboard not found (confirmed) | clock 05:59
# [00:02:00] DEN : UTA | 50 : 45 | 2Q | 05:59
# [00:02:01] DEN : UTA | 50 : 45 | 2Q | 05:59
# [00:02:02] DEN : UTA | 50 : 45 | 2Q | 05:58
# [00:02:03] DEN : UTA | 50 : 45 | 2Q | 05:58
# [00:02:04] DEN : UTA | 50 : 45 | 2Q | 05:58
# [00:02:05] DEN : UTA | 50 : 45 | 2Q | 05:58
# [00:02:06] DEN : UTA | 50 : 45 | 2Q | 05:58
# [00:02:07] DEN : UTA | 50 : 45 | 2Q | 05:58
# [00:02:08] DEN : UTA | 50 : 45 | 2Q | 05:58
# [00:02:09] DEN : UTA | 50 : 45 | 2Q | 05:58
# [00:02:10] DEN : UTA | 50 : 45 | 2Q | 05:58
# [00:02:11] DEN : UTA | 50 : 45 | 2Q | 05:58
# [00:02:12] DEN : UTA | 50 : 45 | 2Q | 05:57
# [00:02:13] DEN : UTA | 50 : 45 | 2Q | 05:56
# [00:02:14] DEN : UTA | 50 : 45 | 2Q | 05:55
# [00:02:15] DEN : UTA | 50 : 45 | 2Q | 05:54
# [00:02:16] DEN : UTA | 50 : 45 | 2Q | 05:53
# [00:02:17] DEN : UTA | 50 : 45 | 2Q | 05:52
# [00:02:18] DEN : UTA | 50 : 45 | 2Q | 05:51
# [00:02:19] DEN : UTA | 50 : 45 | 2Q | 05:50
# [00:02:20] DEN : UTA | 50 : 45 | 2Q | 05:49
# [00:02:21] DEN : UTA | 50 : 45 | 2Q | 05:48
# [00:02:22] DEN : UTA | 50 : 45 | 2Q | 05:47
# [00:02:23] DEN : UTA | 50 : 45 | 2Q | 05:47
# [00:02:24] DEN : UTA | 50 : 45 | 2Q | 05:45
# [00:02:25] DEN : UTA | 50 : 45 | 2Q | 05:45
# [00:02:26] DEN : UTA | 50 : 45 | 2Q | 05:45
# [00:02:27] DEN : UTA | 50 : 45 | 2Q | 05:45
# [00:02:28] DEN : UTA | 50 : 45 | 2Q | 05:45
# [00:02:29] DEN : UTA | 50 : 45 | 2Q | 05:45
# [00:02:30] scoreboard not found (candidate 1/3) | clock 05:45
# [00:02:31] scoreboard not found (candidate 2/3) | clock 05:45
# [00:02:32] DEN : UTA | 62 : 45 | 2Q | 05:45
#            -> possible OCR score correction: 62:45 -> 52:45 (1 votes)
# [00:02:33] scoreboard not found (candidate 1/3) | clock 05:45
# [00:02:34] scoreboard not found (candidate 2/3) | clock 05:45
# [00:02:35] scoreboard not found (confirmed) | clock 05:45
# [00:02:36] scoreboard not found (confirmed) | clock 05:45
# [00:02:37] scoreboard not found (confirmed) | clock 05:45
# [00:02:38] scoreboard not found (confirmed) | clock 05:45
# [00:02:39] scoreboard not found (confirmed) | clock 05:45
# [00:02:40] scoreboard not found (confirmed) | clock 05:45
# [00:02:41] DEN : UTA | 62 : 45 | 2Q | 05:45
#            -> possible OCR score correction: 62:45 -> 52:45 (2 votes)
#            -> corrected score change recorded: 52:45 at 00:02:32
# [00:02:42] scoreboard not found (candidate 1/3) | clock 05:45
# [00:02:43] scoreboard not found (candidate 2/3) | clock 05:45
# [00:02:44] scoreboard not found (confirmed) | clock 05:45
# [00:02:45] scoreboard not found (confirmed) | clock 05:45
# [00:02:46] scoreboard not found (confirmed) | clock 05:45
# [00:02:47] DEN : UTA | 52 : 45 | 2Q | 05:45
# [00:02:48] scoreboard not found (candidate 1/3) | clock 05:45
# [00:02:49] scoreboard not found (candidate 2/3) | clock 05:45
# [00:02:50] scoreboard not found (confirmed) | clock 05:45
# [00:02:51] scoreboard not found (confirmed) | clock 05:45
# [00:02:52] scoreboard not found (confirmed) | clock 05:45
# [00:02:53] scoreboard not found (confirmed) | clock 05:45
# [00:02:54] scoreboard not found (confirmed) | clock 05:45
# [00:02:55] scoreboard not found (confirmed) | clock 05:45
# [00:02:56] scoreboard not found (confirmed) | clock 05:45
# [00:02:57] scoreboard not found (confirmed) | clock 05:45
# [00:02:58] scoreboard not found (confirmed) | clock 05:45
# [00:02:59] scoreboard not found (confirmed) | clock 05:45
# [00:03:00] scoreboard not found (confirmed) | clock 05:45
# [00:03:01] scoreboard not found (confirmed) | clock 05:45
# [00:03:02] scoreboard not found (confirmed) | clock 05:45
# [00:03:03] scoreboard not found (confirmed) | clock 05:45
# [00:03:04] scoreboard not found (confirmed) | clock 05:45
# [00:03:05] scoreboard not found (confirmed) | clock 05:45
# [00:03:06] scoreboard not found (confirmed) | clock 05:45
# [00:03:07] scoreboard not found (confirmed) | clock 05:45
# [00:03:08] scoreboard not found (confirmed) | clock 05:45
# [00:03:09] scoreboard not found (confirmed) | clock 05:45
#            -> long confirmed missing detected: 20 confirmed missing samples (total missing=22), OCR clock resync mode
#            -> clock resynced after long confirmed missing: 05:45 -> 05:27 (drop=18.0s, limit=300s)
# [00:03:10] DEN : UTA | 52 : 45 | 2Q | 05:27
# [00:03:11] DEN : UTA | 52 : 45 | 2Q | 05:27
# [00:03:12] scoreboard not found (candidate 1/3) | clock 05:27
# [00:03:13] scoreboard not found (candidate 2/3) | clock 05:27
# [00:03:14] scoreboard not found (confirmed) | clock 05:27
# [00:03:15] scoreboard not found (confirmed) | clock 05:27
# [00:03:16] scoreboard not found (confirmed) | clock 05:27
# [00:03:17] scoreboard not found (confirmed) | clock 05:27
# [00:03:18] scoreboard not found (confirmed) | clock 05:27
# [00:03:19] scoreboard not found (confirmed) | clock 05:27
# [00:03:20] scoreboard not found (confirmed) | clock 05:27
# [00:03:21] scoreboard not found (confirmed) | clock 05:27
# [00:03:22] scoreboard not found (confirmed) | clock 05:27
# [00:03:23] scoreboard not found (confirmed) | clock 05:27
# [00:03:24] scoreboard not found (confirmed) | clock 05:27
# [00:03:25] scoreboard not found (confirmed) | clock 05:27
#            -> long confirmed missing detected: 12 confirmed missing samples (total missing=14), OCR clock resync mode
#            -> rejected long-missing clock OCR, keep previous clock: last=05:27, raw=05:27, limit=300s
# [00:03:26] DEN : UTA | 52 : 45 | 2Q | 05:27
# [00:03:27] DEN : UTA | 52 : 45 | 2Q | 05:27
# [00:03:28] DEN : UTA | 52 : 45 | 2Q | 05:27
# [00:03:29] DEN : UTA | 52 : 45 | 2Q | 05:26
# [00:03:30] DEN : UTA | 52 : 45 | 2Q | 05:26
# [00:03:31] DEN : UTA | 52 : 45 | 2Q | 05:26
# [00:03:32] scoreboard not found (candidate 1/3) | clock 05:26
# [00:03:33] scoreboard not found (candidate 2/3) | clock 05:26
# [00:03:34] scoreboard not found (confirmed) | clock 05:26
# [00:03:35] scoreboard not found (confirmed) | clock 05:26
# [00:03:36] scoreboard not found (confirmed) | clock 05:26
# [00:03:37] scoreboard not found (confirmed) | clock 05:26
# [00:03:38] DEN : UTA | 52 : 45 | 2Q | 05:26
# [00:03:39] DEN : UTA | 52 : 45 | 2Q | 05:26
# [00:03:40] DEN : UTA | 52 : 45 | 2Q | 05:26
# [00:03:41] DEN : UTA | 52 : 45 | 2Q | 05:26
# [00:03:42] DEN : UTA | 52 : 45 | 2Q | 05:26
# [00:03:43] DEN : UTA | 52 : 45 | 2Q | 05:26
# [00:03:44] DEN : UTA | 52 : 45 | 2Q | 05:26
# [00:03:45] scoreboard not found (candidate 1/3) | clock 05:26
# [00:03:46] scoreboard not found (candidate 2/3) | clock 05:26
# [00:03:47] scoreboard not found (confirmed) | clock 05:26
# [00:03:48] scoreboard not found (confirmed) | clock 05:26
# [00:03:49] DEN : UTA | 52 : 46 | 2Q | 05:25
#            -> possible valid score change: 52:45 -> 52:46 (1/2 votes)
# [00:03:50] DEN : UTA | 52 : 46 | 2Q | 05:24
#            -> possible valid score change: 52:45 -> 52:46 (2/2 votes)
#            -> score change confirmed: 52:46 at 00:03:49
# [00:03:51] DEN : UTA | 52 : 46 | 2Q | 05:23
# [00:03:52] DEN : UTA | 52 : 46 | 2Q | 05:22
# [00:03:53] DEN : UTA | 52 : 46 | 2Q | 05:21
# [00:03:54] scoreboard not found (candidate 1/3) | clock 05:21
# [00:03:55] scoreboard not found (candidate 2/3) | clock 05:21
# [00:03:56] scoreboard not found (confirmed) | clock 05:21
# [00:03:57] DEN : UTA | 52 : 46 | 2Q | 05:17
# [00:03:58] DEN : UTA | 52 : 46 | 2Q | 05:16
# [00:03:59] DEN : UTA | 52 : 46 | 2Q | 05:16
# [00:04:00] DEN : UTA | 52 : 46 | 2Q | 05:16
# [00:04:01] DEN : UTA | 52 : 46 | 2Q | 05:16
# [00:04:02] DEN : UTA | 52 : 46 | 2Q | 05:15
# [00:04:03] DEN : UTA | 52 : 46 | 2Q | 05:15
# [00:04:04] DEN : UTA | 52 : 46 | 2Q | 05:15
# [00:04:05] DEN : UTA | 52 : 46 | 2Q | 05:15
# [00:04:06] DEN : UTA | 52 : 46 | 2Q | 05:15
# [00:04:07] DEN : UTA | 52 : 46 | 2Q | 05:15
# [00:04:08] DEN : UTA | 52 : 46 | 2Q | 05:15
# [00:04:09] DEN : UTA | 52 : 46 | 2Q | 05:15
# [00:04:10] scoreboard not found (candidate 1/3) | clock 05:15
# [00:04:11] DEN : UTA | 52 : 46 | 2Q | 05:15
# [00:04:12] scoreboard not found (candidate 1/3) | clock 05:15
# [00:04:13] scoreboard not found (candidate 2/3) | clock 05:15
# [00:04:14] scoreboard not found (confirmed) | clock 05:15
# [00:04:15] scoreboard not found (confirmed) | clock 05:15
# [00:04:16] scoreboard not found (confirmed) | clock 05:15
# [00:04:17] scoreboard not found (confirmed) | clock 05:15
# [00:04:18] scoreboard not found (confirmed) | clock 05:15
# [00:04:19] scoreboard not found (confirmed) | clock 05:15
# [00:04:20] scoreboard not found (confirmed) | clock 05:15
# [00:04:21] scoreboard not found (confirmed) | clock 05:15
# [00:04:22] DEN : UTA | 52 : 46 | 2Q | 05:15
# [00:04:23] DEN : UTA | 52 : 46 | 2Q | 05:15
# [00:04:24] DEN : UTA | 52 : 46 | 2Q | 05:15
# [00:04:25] scoreboard not found (candidate 1/3) | clock 05:15
# [00:04:26] scoreboard not found (candidate 2/3) | clock 05:15
# [00:04:27] scoreboard not found (confirmed) | clock 05:15
# [00:04:28] scoreboard not found (confirmed) | clock 05:15
# [00:04:29] DEN : UTA | 52 : 46 | 2Q | 05:12
# [00:04:30] DEN : UTA | 52 : 46 | 2Q | 05:11
# [00:04:31] scoreboard not found (candidate 1/3) | clock 05:11
# [00:04:32] DEN : UTA | 52 : 46 | 2Q | 05:09
# [00:04:33] DEN : UTA | 52 : 46 | 2Q | 05:08
# [00:04:34] DEN : UTA | 52 : 46 | 2Q | 05:07
# [00:04:35] DEN : UTA | 52 : 46 | 2Q | 05:06
# [00:04:36] scoreboard not found (candidate 1/3) | clock 05:06
# [00:04:37] scoreboard not found (candidate 2/3) | clock 05:06
# [00:04:38] scoreboard not found (confirmed) | clock 05:06
# [00:04:39] scoreboard not found (confirmed) | clock 05:06
# [00:04:40] scoreboard not found (confirmed) | clock 05:06
# [00:04:41] DEN : UTA | 52 : 46 | 2Q | 05:00
# [00:04:42] DEN : UTA | 52 : 46 | 2Q | 04:59
# [00:04:43] DEN : UTA | 52 : 46 | 2Q | 04:58
# [00:04:44] DEN : UTA | 52 : 46 | 2Q | 04:57
# [00:04:45] DEN : UTA | 52 : 46 | 2Q | 04:56
# [00:04:46] scoreboard not found (candidate 1/3) | clock 04:56
# [00:04:47] scoreboard not found (candidate 2/3) | clock 04:56
# [00:04:48] scoreboard not found (confirmed) | clock 04:56
# [00:04:49] scoreboard not found (confirmed) | clock 04:56
# [00:04:50] DEN : UTA | 52 : 46 | 2Q | 04:51
# [00:04:51] DEN : UTA | 52 : 46 | 2Q | 04:50
# [00:04:52] scoreboard not found (candidate 1/3) | clock 04:50
# [00:04:53] DEN : UTA | 52 : 46 | 2Q | 04:48
# [00:04:54] DEN : UTA | 52 : 46 | 2Q | 04:47
# [00:04:55] DEN : UTA | 52 : 46 | 2Q | 04:46
# [00:04:56] DEN : UTA | 52 : 46 | 2Q | 04:45
# [00:04:57] DEN : UTA | 55 : 46 | 2Q | 04:45
#            -> possible valid score change: 52:46 -> 55:46 (1/2 votes)
# [00:04:58] DEN : UTA | 54 : 46 | 2Q | 04:45
#            -> possible valid score change: 52:46 -> 54:46 (1/2 votes)
# [00:04:59] DEN : UTA | 54 : 46 | 2Q | 04:45
#            -> possible valid score change: 52:46 -> 54:46 (2/2 votes)
#            -> score change confirmed: 54:46 at 00:04:58
# [00:05:00] DEN : UTA | 54 : 46 | 2Q | 04:44
# [00:05:01] scoreboard not found (candidate 1/3) | clock 04:44
# [00:05:02] scoreboard not found (candidate 2/3) | clock 04:44
# [00:05:03] scoreboard not found (confirmed) | clock 04:44
# [00:05:04] scoreboard not found (confirmed) | clock 04:44
# [00:05:05] scoreboard not found (confirmed) | clock 04:44
# [00:05:06] scoreboard not found (confirmed) | clock 04:44
# [00:05:07] scoreboard not found (confirmed) | clock 04:44
# [00:05:08] scoreboard not found (confirmed) | clock 04:44
# [00:05:09] scoreboard not found (confirmed) | clock 04:44
# [00:05:10] scoreboard not found (confirmed) | clock 04:44
# [00:05:11] DEN : UTA | 54 : 57 | 2Q | 04:44
#            -> possible OCR score correction: 54:57 -> 54:47 (1 votes)
# [00:05:12] scoreboard not found (candidate 1/3) | clock 04:44
# [00:05:13] scoreboard not found (candidate 2/3) | clock 04:44
# [00:05:14] scoreboard not found (confirmed) | clock 04:44
# [00:05:15] scoreboard not found (confirmed) | clock 04:44
# [00:05:16] scoreboard not found (confirmed) | clock 04:44
# [00:05:17] scoreboard not found (confirmed) | clock 04:44
# [00:05:18] scoreboard not found (confirmed) | clock 04:44
# [00:05:19] scoreboard not found (confirmed) | clock 04:44
# [00:05:20] scoreboard not found (confirmed) | clock 04:44
# [00:05:21] scoreboard not found (confirmed) | clock 04:44
# [00:05:22] scoreboard not found (confirmed) | clock 04:44
# [00:05:23] DEN : UTA | 54 : 58 | 2Q | 04:44
#            -> possible OCR score correction: 54:58 -> 54:48 (1 votes)
# [00:05:24] DEN : UTA | 54 : 46 | 2Q | 04:44
# [00:05:25] DEN : UTA | 54 : 46 | 2Q | 04:44
# [00:05:26] scoreboard not found (candidate 1/3) | clock 04:44
# [00:05:27] DEN : UTA | 54 : 46 | 2Q | 04:44
# [00:05:28] DEN : UTA | 54 : 46 | 2Q | 04:44
# [00:05:29] DEN : UTA | 54 : 46 | 2Q | 04:44
# [00:05:30] DEN : UTA | 54 : 46 | 2Q | 04:44
# [00:05:31] DEN : UTA | 54 : 46 | 2Q | 04:44
# [00:05:32] scoreboard not found (candidate 1/3) | clock 04:44
# [00:05:33] DEN : UTA | 54 : 46 | 2Q | 04:44
# [00:05:34] DEN : UTA | 54 : 46 | 2Q | 04:44
# [00:05:35] DEN : UTA | 54 : 46 | 2Q | 04:44
# [00:05:36] DEN : UTA | 54 : 46 | 2Q | 04:44
# [00:05:37] DEN : UTA | 54 : 46 | 2Q | 04:44
# [00:05:38] DEN : UTA | 54 : 46 | 2Q | 04:44
# [00:05:39] DEN : UTA | 54 : 46 | 2Q | 04:44
# [00:05:40] DEN : UTA | 54 : 46 | 2Q | 04:44
# [00:05:41] scoreboard not found (candidate 1/3) | clock 04:44
# [00:05:42] DEN : UTA | 54 : 49 | 2Q | 04:44
#            -> possible valid score change: 54:46 -> 54:49 (1/2 votes)
# [00:05:43] DEN : UTA | 54 : 49 | 2Q | 04:44
#            -> possible valid score change: 54:46 -> 54:49 (2/2 votes)
#            -> score change confirmed: 54:49 at 00:05:42
# [00:05:44] DEN : UTA | 54 : 49 | 2Q | 04:44
# [00:05:45] DEN : UTA | 54 : 49 | 2Q | 04:44
# [00:05:46] scoreboard not found (candidate 1/3) | clock 04:44
# [00:05:47] scoreboard not found (candidate 2/3) | clock 04:44
# [00:05:48] scoreboard not found (confirmed) | clock 04:44
# [00:05:49] scoreboard not found (confirmed) | clock 04:44
# [00:05:50] scoreboard not found (confirmed) | clock 04:44
# [00:05:51] scoreboard not found (confirmed) | clock 04:44
# [00:05:52] scoreboard not found (confirmed) | clock 04:44
# [00:05:53] scoreboard not found (confirmed) | clock 04:44
# [00:05:54] scoreboard not found (confirmed) | clock 04:44
# [00:05:55] DEN : UTA | 54 : 49 | 2Q | 04:44
# [00:05:56] scoreboard not found (candidate 1/3) | clock 04:44
# [00:05:57] DEN : UTA | 56 : 49 | 2Q | 04:44
#            -> possible valid score change: 54:49 -> 56:49 (1/2 votes)
# [00:05:58] DEN : UTA | 56 : 49 | 2Q | 04:44
#            -> possible valid score change: 54:49 -> 56:49 (2/2 votes)
#            -> score change confirmed: 56:49 at 00:05:57
# [00:05:59] DEN : UTA | 56 : 49 | 2Q | 04:44
# [00:06:00] DEN : UTA | 56 : 49 | 2Q | 04:44
# [00:06:01] DEN : UTA | 56 : 49 | 2Q | 04:44
# [00:06:02] DEN : UTA | 56 : 49 | 2Q | 04:44
# [00:06:03] scoreboard not found (candidate 1/3) | clock 04:44
# [00:06:04] scoreboard not found (candidate 2/3) | clock 04:44
# [00:06:05] DEN : UTA | 56 : 49 | 2Q | 04:44
# [00:06:06] DEN : UTA | 56 : 49 | 2Q | 04:44
# [00:06:07] DEN : UTA | 56 : 49 | 2Q | 04:44
# [00:06:08] DEN : UTA | 56 : 49 | 2Q | 04:44
# [00:06:09] DEN : UTA | 56 : 49 | 2Q | 04:44
# [00:06:10] DEN : UTA | 56 : 49 | 2Q | 04:44
# [00:06:11] DEN : UTA | 56 : 49 | 2Q | 04:44
# [00:06:12] DEN : UTA | 56 : 49 | 2Q | 04:44
# [00:06:13] DEN : UTA | 56 : 49 | 2Q | 04:44
# [00:06:14] DEN : UTA | 56 : 49 | 2Q | 04:44
# [00:06:15] DEN : UTA | 56 : 49 | 2Q | 04:44
# [00:06:16] DEN : UTA | 56 : 49 | 2Q | 04:44
# [00:06:17] DEN : UTA | 56 : 49 | 2Q | 04:44
# [00:06:18] scoreboard not found (candidate 1/3) | clock 04:44
# [00:06:19] DEN : UTA | 56 : 49 | 2Q | 04:44
# [00:06:20] DEN : UTA | 56 : 49 | 2Q | 04:44
# [00:06:21] DEN : UTA | 56 : 49 | 2Q | 04:44
# [00:06:22] scoreboard not found (candidate 1/3) | clock 04:44
# [00:06:23] DEN : UTA | 56 : 49 | 2Q | 04:44
# [00:06:24] DEN : UTA | 56 : 49 | 2Q | 04:44
# [00:06:25] DEN : UTA | 56 : 49 | 2Q | 04:44
# [00:06:26] DEN : UTA | 56 : 49 | 2Q | 04:44
# [00:06:27] scoreboard not found (candidate 1/3) | clock 04:44
# [00:06:28] scoreboard not found (candidate 2/3) | clock 04:44
# [00:06:29] DEN : UTA | 56 : 49 | 2Q | 04:44
# [00:06:30] scoreboard not found (candidate 1/3) | clock 04:44
# [00:06:31] scoreboard not found (candidate 2/3) | clock 04:44
# [00:06:32] scoreboard not found (confirmed) | clock 04:44
# [00:06:33] scoreboard not found (confirmed) | clock 04:44
# [00:06:34] scoreboard not found (confirmed) | clock 04:44
# [00:06:35] scoreboard not found (confirmed) | clock 04:44
# [00:06:36] scoreboard not found (confirmed) | clock 04:44
# [00:06:37] scoreboard not found (confirmed) | clock 04:44
# [00:06:38] scoreboard not found (confirmed) | clock 04:44
# [00:06:39] scoreboard not found (confirmed) | clock 04:44
# [00:06:40] scoreboard not found (confirmed) | clock 04:44
# [00:06:41] scoreboard not found (confirmed) | clock 04:44
# [00:06:42] scoreboard not found (confirmed) | clock 04:44
# [00:06:43] scoreboard not found (confirmed) | clock 04:44
# [00:06:44] scoreboard not found (confirmed) | clock 04:44
# [00:06:45] scoreboard not found (confirmed) | clock 04:44
# [00:06:46] scoreboard not found (confirmed) | clock 04:44
# [00:06:47] scoreboard not found (confirmed) | clock 04:44
# [00:06:48] scoreboard not found (confirmed) | clock 04:44
#            -> long confirmed missing detected: 17 confirmed missing samples (total missing=19), OCR clock resync mode
#            -> clock resynced after long confirmed missing: 04:44 -> 03:16 (drop=88.0s, limit=300s)
# [00:06:49] DEN : UTA | 59 : 49 | 2Q | 03:16
#            -> possible valid score change: 56:49 -> 59:49 (1/2 votes)
# [00:06:50] DEN : UTA | 59 : 49 | 2Q | 03:16
#            -> possible valid score change: 56:49 -> 59:49 (2/2 votes)
#            -> score change confirmed: 59:49 at 00:06:49
# [00:06:51] DEN : UTA | 59 : 49 | 2Q | 03:16
# [00:06:52] DEN : UTA | 59 : 49 | 2Q | 03:13
# [00:06:53] DEN : UTA | 59 : 49 | 2Q | 03:12
# [00:06:54] scoreboard not found (candidate 1/3) | clock 03:12
# [00:06:55] scoreboard not found (candidate 2/3) | clock 03:12
# [00:06:56] scoreboard not found (confirmed) | clock 03:12
# [00:06:57] scoreboard not found (confirmed) | clock 03:12
# [00:06:58] scoreboard not found (confirmed) | clock 03:12
# [00:06:59] scoreboard not found (confirmed) | clock 03:12
# [00:07:00] scoreboard not found (confirmed) | clock 03:12
# [00:07:01] scoreboard not found (confirmed) | clock 03:12
# [00:07:02] scoreboard not found (confirmed) | clock 03:12
# [00:07:03] scoreboard not found (confirmed) | clock 03:12
# [00:07:04] scoreboard not found (confirmed) | clock 03:12
# [00:07:05] scoreboard not found (confirmed) | clock 03:12
# [00:07:06] scoreboard not found (confirmed) | clock 03:12
# [00:07:07] scoreboard not found (confirmed) | clock 03:12
# [00:07:08] scoreboard not found (confirmed) | clock 03:12
# [00:07:09] scoreboard not found (confirmed) | clock 03:12
# [00:07:10] scoreboard not found (confirmed) | clock 03:12
# [00:07:11] scoreboard not found (confirmed) | clock 03:12
# [00:07:12] scoreboard not found (confirmed) | clock 03:12
# [00:07:13] scoreboard not found (confirmed) | clock 03:12
# [00:07:14] scoreboard not found (confirmed) | clock 03:12
# [00:07:15] scoreboard not found (confirmed) | clock 03:12
# [00:07:16] scoreboard not found (confirmed) | clock 03:12
#            -> long confirmed missing detected: 21 confirmed missing samples (total missing=23), OCR clock resync mode
#            -> clock resynced after long confirmed missing: 03:12 -> 03:11 (drop=1.0s, limit=300s)
# [00:07:17] DEN : UTA | 59 : 49 | 2Q | 03:11
# [00:07:18] DEN : UTA | 59 : 49 | 2Q | 03:11
# [00:07:19] DEN : UTA | 59 : 49 | 2Q | 03:11
# [00:07:20] DEN : UTA | 59 : 49 | 2Q | 03:11
# [00:07:21] scoreboard not found (candidate 1/3) | clock 03:11
# [00:07:22] scoreboard not found (candidate 2/3) | clock 03:11
# [00:07:23] scoreboard not found (confirmed) | clock 03:11
# [00:07:24] scoreboard not found (confirmed) | clock 03:11
# [00:07:25] scoreboard not found (confirmed) | clock 03:11
# [00:07:26] scoreboard not found (confirmed) | clock 03:11
# [00:07:27] scoreboard not found (confirmed) | clock 03:11
# [00:07:28] scoreboard not found (confirmed) | clock 03:11
# [00:07:29] scoreboard not found (confirmed) | clock 03:11
# [00:07:30] scoreboard not found (confirmed) | clock 03:11
# [00:07:31] scoreboard not found (confirmed) | clock 03:11
# [00:07:32] scoreboard not found (confirmed) | clock 03:11
# [00:07:33] scoreboard not found (confirmed) | clock 03:11
# [00:07:34] scoreboard not found (confirmed) | clock 03:11
# [00:07:35] scoreboard not found (confirmed) | clock 03:11
# [00:07:36] scoreboard not found (confirmed) | clock 03:11
# [00:07:37] scoreboard not found (confirmed) | clock 03:11
# [00:07:38] scoreboard not found (confirmed) | clock 03:11
# [00:07:39] scoreboard not found (confirmed) | clock 03:11
# [00:07:40] scoreboard not found (confirmed) | clock 03:11
# [00:07:41] scoreboard not found (confirmed) | clock 03:11
# [00:07:42] scoreboard not found (confirmed) | clock 03:11
# [00:07:43] scoreboard not found (confirmed) | clock 03:11
# [00:07:44] scoreboard not found (confirmed) | clock 03:11
# [00:07:45] scoreboard not found (confirmed) | clock 03:11
# [00:07:46] scoreboard not found (confirmed) | clock 03:11
# [00:07:47] scoreboard not found (confirmed) | clock 03:11
# [00:07:48] scoreboard not found (confirmed) | clock 03:11
# [00:07:49] scoreboard not found (confirmed) | clock 03:11
# [00:07:50] scoreboard not found (confirmed) | clock 03:11
# [00:07:51] scoreboard not found (confirmed) | clock 03:11
# [00:07:52] scoreboard not found (confirmed) | clock 03:11
# [00:07:53] scoreboard not found (confirmed) | clock 03:11
# [00:07:54] scoreboard not found (confirmed) | clock 03:11
# [00:07:55] scoreboard not found (confirmed) | clock 03:11
# [00:07:56] scoreboard not found (confirmed) | clock 03:11
# [00:07:57] scoreboard not found (confirmed) | clock 03:11
# [00:07:58] scoreboard not found (confirmed) | clock 03:11
# [00:07:59] scoreboard not found (confirmed) | clock 03:11
# [00:08:00] scoreboard not found (confirmed) | clock 03:11
# [00:08:01] scoreboard not found (confirmed) | clock 03:11
# [00:08:02] scoreboard not found (confirmed) | clock 03:11
#            -> long confirmed missing detected: 40 confirmed missing samples (total missing=42), OCR clock resync mode
#            -> clock resynced after long confirmed missing: 03:11 -> 02:51 (drop=20.0s, limit=300s)
# [00:08:03] DEN : UTA | 61 : 51 | 2Q | 02:51
#            -> possible score resync: 59:49 -> 61:51 (1 votes)
# [00:08:04] DEN : UTA | 61 : 51 | 2Q | 02:50
#            -> possible score resync: 59:49 -> 61:51 (2 votes)
# [00:08:05] DEN : UTA | 61 : 51 | 2Q | 02:49
#            -> possible score resync: 59:49 -> 61:51 (3 votes)
#            -> score resynced after repeated read: 61:51 at 00:08:03
# [00:08:06] DEN : UTA | 61 : 51 | 2Q | 02:48
# [00:08:07] scoreboard not found (candidate 1/3) | clock 02:48
# [00:08:08] scoreboard not found (candidate 2/3) | clock 02:48
# [00:08:09] DEN : UTA | 61 : 51 | 2Q | 02:45
# [00:08:10] scoreboard not found (candidate 1/3) | clock 02:45
# [00:08:11] DEN : UTA | 61 : 51 | 2Q | 02:43
# [00:08:12] DEN : UTA | 61 : 51 | 2Q | 02:42
# [00:08:13] DEN : UTA | 61 : 51 | 2Q | 02:41
# [00:08:14] DEN : UTA | 61 : 51 | 2Q | 02:40
# [00:08:15] DEN : UTA | 61 : 51 | 2Q | 02:39
# [00:08:16] DEN : UTA | 61 : 51 | 2Q | 02:38
# [00:08:17] DEN : UTA | 61 : 51 | 2Q | 02:37
# [00:08:18] DEN : UTA | 61 : 51 | 2Q | 02:36
# [00:08:19] DEN : UTA | 61 : 51 | 2Q | 02:35
# [00:08:20] DEN : UTA | 61 : 51 | 2Q | 02:34
# [00:08:21] DEN : UTA | 61 : 51 | 2Q | 02:33
# [00:08:22] DEN : UTA | 61 : 51 | 2Q | 02:32
# [00:08:23] DEN : UTA | 61 : 51 | 2Q | 02:31
# [00:08:24] DEN : UTA | 61 : 51 | 2Q | 02:30
# [00:08:25] DEN : UTA | 61 : 51 | 2Q | 02:29
# [00:08:26] DEN : UTA | 61 : 51 | 2Q | 02:28
# [00:08:27] DEN : UTA | 61 : 51 | 2Q | 02:27
# [00:08:28] DEN : UTA | 61 : 51 | 2Q | 02:26
# [00:08:29] scoreboard not found (candidate 1/3) | clock 02:26
# [00:08:30] scoreboard not found (candidate 2/3) | clock 02:26
# [00:08:31] scoreboard not found (confirmed) | clock 02:26
# [00:08:32] DEN : UTA | 61 : 54 | 2Q | 02:22
#            -> possible valid score change: 61:51 -> 61:54 (1/2 votes)
# [00:08:33] DEN : UTA | 61 : 54 | 2Q | 02:21
#            -> possible valid score change: 61:51 -> 61:54 (2/2 votes)
#            -> score change confirmed: 61:54 at 00:08:32
# [00:08:34] DEN : UTA | 61 : 54 | 2Q | 02:20
# [00:08:35] DEN : UTA | 61 : 54 | 2Q | 02:19
# [00:08:36] DEN : UTA | 61 : 54 | 2Q | 02:18
# [00:08:37] scoreboard not found (candidate 1/3) | clock 02:18
# [00:08:38] DEN : UTA | 61 : 54 | 2Q | 02:16
# [00:08:39] DEN : UTA | 61 : 54 | 2Q | 02:15
# [00:08:40] scoreboard not found (candidate 1/3) | clock 02:15
# [00:08:41] DEN : UTA | 61 : 54 | 2Q | 02:13
# [00:08:42] scoreboard not found (candidate 1/3) | clock 02:13
# [00:08:43] scoreboard not found (candidate 2/3) | clock 02:13
# [00:08:44] DEN : UTA | 61 : 54 | 2Q | 02:10
# [00:08:45] DEN : UTA | 61 : 54 | 2Q | 02:09
# [00:08:46] DEN : UTA | 61 : 54 | 2Q | 02:08
# [00:08:47] DEN : UTA | 61 : 54 | 2Q | 02:07
# [00:08:48] DEN : UTA | 61 : 54 | 2Q | 02:06
# [00:08:49] DEN : UTA | 61 : 54 | 2Q | 02:05
# [00:08:50] DEN : UTA | 61 : 54 | 2Q | 02:04
# [00:08:51] scoreboard not found (candidate 1/3) | clock 02:04
# [00:08:52] DEN : UTA | 61 : 54 | 2Q | 02:02
# [00:08:53] scoreboard not found (candidate 1/3) | clock 02:02
# [00:08:54] scoreboard not found (candidate 2/3) | clock 02:02
# [00:08:55] scoreboard not found (confirmed) | clock 02:02
# [00:08:56] scoreboard not found (confirmed) | clock 02:02
# [00:08:57] DEN : UTA | 61 : 54 | 2Q | 01:58
# [00:08:58] DEN : UTA | 61 : 54 | 2Q | 01:58
# [00:08:59] DEN : UTA | 61 : 54 | 2Q | 01:58
# [00:09:00] DEN : UTA | 61 : 54 | 2Q | 01:58
# [00:09:01] DEN : UTA | 61 : 54 | 2Q | 01:57
# [00:09:02] scoreboard not found (candidate 1/3) | clock 01:57
# [00:09:03] scoreboard not found (candidate 2/3) | clock 01:57
# [00:09:04] DEN : UTA | 61 : 55 | 2Q | 01:57
#            -> possible valid score change: 61:54 -> 61:55 (1/2 votes)
# [00:09:05] scoreboard not found (candidate 1/3) | clock 01:57
# [00:09:06] scoreboard not found (candidate 2/3) | clock 01:57
# [00:09:07] scoreboard not found (confirmed) | clock 01:57
# [00:09:08] scoreboard not found (confirmed) | clock 01:57
# [00:09:09] scoreboard not found (confirmed) | clock 01:57
# [00:09:10] scoreboard not found (confirmed) | clock 01:57
# [00:09:11] scoreboard not found (confirmed) | clock 01:57
# [00:09:12] scoreboard not found (confirmed) | clock 01:57
# [00:09:13] DEN : UTA | 61 : 54 | 2Q | 01:56
# [00:09:14] DEN : UTA | 61 : 54 | 2Q | 01:55
# [00:09:15] DEN : UTA | 61 : 54 | 2Q | 01:54
# [00:09:16] DEN : UTA | 61 : 54 | 2Q | 01:53
# [00:09:17] scoreboard not found (candidate 1/3) | clock 01:53
# [00:09:18] scoreboard not found (candidate 2/3) | clock 01:53
# [00:09:19] DEN : UTA | 61 : 54 | 2Q | 01:50
# [00:09:20] DEN : UTA | 61 : 54 | 2Q | 01:49
# [00:09:21] DEN : UTA | 61 : 54 | 2Q | 01:48
# [00:09:22] DEN : UTA | 61 : 54 | 2Q | 01:47
# [00:09:23] DEN : UTA | 61 : 54 | 2Q | 01:46
# [00:09:24] scoreboard not found (candidate 1/3) | clock 01:46
# [00:09:25] DEN : UTA | 61 : 54 | 2Q | 01:44
# [00:09:26] scoreboard not found (candidate 1/3) | clock 01:44
# [00:09:27] DEN : UTA | 61 : 54 | 2Q | 01:42
# [00:09:28] DEN : UTA | 61 : 54 | 2Q | 01:41
# [00:09:29] DEN : UTA | 61 : 54 | 2Q | 01:40
# [00:09:30] DEN : UTA | 61 : 54 | 2Q | 01:39
# [00:09:31] DEN : UTA | 61 : 54 | 2Q | 01:38
# [00:09:32] DEN : UTA | 61 : 54 | 2Q | 01:37
# [00:09:33] DEN : UTA | 61 : 54 | 2Q | 01:36
# [00:09:34] DEN : UTA | 61 : 54 | 2Q | 01:35
# [00:09:35] DEN : UTA | 61 : 54 | 2Q | 01:34
# [00:09:36] DEN : UTA | 61 : 54 | 2Q | 01:33
# [00:09:37] DEN : UTA | 61 : 54 | 2Q | 01:32
# [00:09:38] DEN : UTA | 61 : 54 | 2Q | 01:31
# [00:09:39] DEN : UTA | 61 : 54 | 2Q | 01:30
# [00:09:40] scoreboard not found (candidate 1/3) | clock 01:30
# [00:09:41] DEN : UTA | 61 : 54 | 2Q | 01:28
# [00:09:42] DEN : UTA | 61 : 54 | 2Q | 01:27
# [00:09:43] DEN : UTA | 61 : 54 | 2Q | 01:26
# [00:09:44] DEN : UTA | 61 : 54 | 2Q | 01:25
# [00:09:45] scoreboard not found (candidate 1/3) | clock 01:25
# [00:09:46] scoreboard not found (candidate 2/3) | clock 01:25
# [00:09:47] scoreboard not found (confirmed) | clock 01:25
# [00:09:48] scoreboard not found (confirmed) | clock 01:25
# [00:09:49] DEN : UTA | 61 : 54 | 2Q | 01:20
# [00:09:50] DEN : UTA | 61 : 54 | 2Q | 01:19
# [00:09:51] DEN : UTA | 61 : 54 | 2Q | 01:18
# [00:09:52] scoreboard not found (candidate 1/3) | clock 01:18
# [00:09:53] scoreboard not found (candidate 2/3) | clock 01:18
# [00:09:54] DEN : UTA | 61 : 54 | 2Q | 01:15
# [00:09:55] DEN : UTA | 61 : 54 | 2Q | 01:14
# [00:09:56] DEN : UTA | 61 : 54 | 2Q | 01:13
# [00:09:57] scoreboard not found (candidate 1/3) | clock 01:13
# [00:09:58] DEN : UTA | 61 : 54 | 2Q | 01:11
# [00:09:59] DEN : UTA | 61 : 54 | 2Q | 01:10
# [00:10:00] DEN : UTA | 61 : 54 | 2Q | 01:09
# [00:10:01] DEN : UTA | 61 : 54 | 2Q | 01:08
# [00:10:02] DEN : UTA | 61 : 54 | 2Q | 01:07
# [00:10:03] DEN : UTA | 61 : 54 | 2Q | 01:06
# [00:10:04] scoreboard not found (candidate 1/3) | clock 01:06
# [00:10:05] DEN : UTA | 61 : 54 | 2Q | 01:04
# [00:10:06] DEN : UTA | 61 : 54 | 2Q | 01:03
# [00:10:07] DEN : UTA | 61 : 54 | 2Q | 01:02
# [00:10:08] DEN : UTA | 61 : 54 | 2Q | 01:01
# [00:10:09] DEN : UTA | 61 : 54 | 2Q | 01:00
# [00:10:10] DEN : UTA | 61 : 54 | 2Q | 00:59
# [00:10:11] DEN : UTA | 61 : 54 | 2Q | 00:58
# [00:10:12] DEN : UTA | 61 : 54 | 2Q | 00:57
# [00:10:13] DEN : UTA | 61 : 54 | 2Q | 00:56
# [00:10:14] DEN : UTA | 61 : 54 | 2Q | 00:55
# [00:10:15] DEN : UTA | 61 : 54 | 2Q | 00:54
# [00:10:16] DEN : UTA | 61 : 54 | 2Q | 00:53
# [00:10:17] scoreboard not found (candidate 1/3) | clock 00:53
# [00:10:18] DEN : UTA | 61 : 54 | 2Q | 00:51
# [00:10:19] scoreboard not found (candidate 1/3) | clock 00:51
# [00:10:20] DEN : UTA | 61 : 54 | 2Q | 00:49
# [00:10:21] scoreboard not found (candidate 1/3) | clock 00:49
# [00:10:22] scoreboard not found (candidate 2/3) | clock 00:49
# [00:10:23] DEN : UTA | 61 : 54 | 2Q | 00:46
# [00:10:24] DEN : UTA | 61 : 54 | 2Q | 00:45
# [00:10:25] DEN : UTA | 61 : 54 | 2Q | 00:44
# [00:10:26] scoreboard not found (candidate 1/3) | clock 00:44
# [00:10:27] DEN : UTA | 61 : 54 | 2Q | 00:42
# [00:10:28] DEN : UTA | 61 : 54 | 2Q | 00:41
# [00:10:29] scoreboard not found (candidate 1/3) | clock 00:41
# [00:10:30] DEN : UTA | 61 : 54 | 2Q | 00:39
# [00:10:31] scoreboard not found (candidate 1/3) | clock 00:39
# [00:10:32] scoreboard not found (candidate 2/3) | clock 00:39
# [00:10:33] DEN : UTA | 61 : 54 | 2Q | 00:36
# [00:10:34] scoreboard not found (candidate 1/3) | clock 00:36
# [00:10:35] scoreboard not found (candidate 2/3) | clock 00:36
# [00:10:36] scoreboard not found (confirmed) | clock 00:36
# [00:10:37] DEN : UTA | 61 : 54 | 2Q | 00:35
# [00:10:38] DEN : UTA | 61 : 54 | 2Q | 00:35
# [00:10:39] DEN : UTA | 61 : 54 | 2Q | 00:35
# [00:10:40] DEN : UTA | 61 : 54 | 2Q | 00:35
# [00:10:41] scoreboard not found (candidate 1/3) | clock 00:35
# [00:10:42] scoreboard not found (candidate 2/3) | clock 00:35
# [00:10:43] scoreboard not found (confirmed) | clock 00:35
# [00:10:44] scoreboard not found (confirmed) | clock 00:35
# [00:10:45] scoreboard not found (confirmed) | clock 00:35
# [00:10:46] scoreboard not found (confirmed) | clock 00:35
# [00:10:47] scoreboard not found (confirmed) | clock 00:35
# [00:10:48] scoreboard not found (confirmed) | clock 00:35
# [00:10:49] scoreboard not found (confirmed) | clock 00:35
# [00:10:50] scoreboard not found (confirmed) | clock 00:35
# [00:10:51] scoreboard not found (confirmed) | clock 00:35
# [00:10:52] scoreboard not found (confirmed) | clock 00:35
# [00:10:53] scoreboard not found (confirmed) | clock 00:35
# [00:10:54] scoreboard not found (confirmed) | clock 00:35
# [00:10:55] scoreboard not found (confirmed) | clock 00:35
# [00:10:56] scoreboard not found (confirmed) | clock 00:35
# [00:10:57] scoreboard not found (confirmed) | clock 00:35
# [00:10:58] scoreboard not found (confirmed) | clock 00:35
# [00:10:59] scoreboard not found (confirmed) | clock 00:35
#            -> long confirmed missing detected: 17 confirmed missing samples (total missing=19), OCR clock resync mode
#            -> rejected long-missing clock OCR, keep previous clock: last=00:35, raw=00:35, limit=300s
# [00:11:00] DEN : UTA | 61 : 54 | 2Q | 00:35
# [00:11:01] DEN : UTA | 61 : 54 | 2Q | 00:34
# [00:11:02] DEN : UTA | 61 : 54 | 2Q | 00:34
# [00:11:03] DEN : UTA | 61 : 54 | 2Q | 00:34
# [00:11:04] DEN : UTA | 61 : 54 | 2Q | 00:34
# [00:11:05] DEN : UTA | 61 : 54 | 2Q | 00:33
# [00:11:06] DEN : UTA | 61 : 54 | 2Q | 00:32
# [00:11:07] scoreboard not found (candidate 1/3) | clock 00:32
# [00:11:08] scoreboard not found (candidate 2/3) | clock 00:32
# [00:11:09] scoreboard not found (confirmed) | clock 00:32
# [00:11:10] scoreboard not found (confirmed) | clock 00:32
# [00:11:11] DEN : UTA | 61 : 54 | 2Q | 00:32
# [00:11:12] DEN : UTA | 61 : 54 | 2Q | 00:32
# [00:11:13] DEN : UTA | 61 : 54 | 2Q | 00:32
# [00:11:14] DEN : UTA | 61 : 54 | 2Q | 00:32
# [00:11:15] DEN : UTA | 61 : 54 | 2Q | 00:32
# [00:11:16] DEN : UTA | 61 : 54 | 2Q | 00:32
# [00:11:17] scoreboard not found (candidate 1/3) | clock 00:32
# [00:11:18] scoreboard not found (candidate 2/3) | clock 00:32
# [00:11:19] scoreboard not found (confirmed) | clock 00:32
# [00:11:20] DEN : UTA | 61 : 54 | 2Q | 00:32
# [00:11:21] DEN : UTA | 61 : 54 | 2Q | 00:32
# [00:11:22] DEN : UTA | 61 : 54 | 2Q | 00:32
# [00:11:23] DEN : UTA | 61 : 54 | 2Q | 00:32
# [00:11:24] DEN : UTA | 61 : 54 | 2Q | 00:32
# [00:11:25] scoreboard not found (candidate 1/3) | clock 00:32
# [00:11:26] DEN : UTA | 61 : 54 | 2Q | 00:32
# [00:11:27] scoreboard not found (candidate 1/3) | clock 00:32
# [00:11:28] DEN : UTA | 61 : 54 | 2Q | 00:32
# [00:11:29] DEN : UTA | 61 : 54 | 2Q | 00:32
# [00:11:30] DEN : UTA | 61 : 54 | 2Q | 00:32
# [00:11:31] DEN : UTA | 61 : 54 | 2Q | 00:32
# [00:11:32] scoreboard not found (candidate 1/3) | clock 00:32
# [00:11:33] DEN : UTA | 61 : 54 | 2Q | 00:32
# [00:11:34] scoreboard not found (candidate 1/3) | clock 00:32
# [00:11:35] DEN : UTA | 61 : 54 | 2Q | 00:32
# [00:11:36] DEN : UTA | 61 : 54 | 2Q | 00:32
# [00:11:37] DEN : UTA | 61 : 54 | 2Q | 00:32
# [00:11:38] DEN : UTA | 61 : 54 | 2Q | 00:32
# [00:11:39] DEN : UTA | 61 : 54 | 2Q | 00:32
# [00:11:40] DEN : UTA | 61 : 54 | 2Q | 0.5
# [00:11:41] DEN : UTA | 61 : 54 | 2Q | 0.5
# [00:11:42] DEN : UTA | 61 : 54 | 2Q | 0.5
# [00:11:43] DEN : UTA | 61 : 54 | 2Q | 0.5
# [00:11:44] DEN : UTA | 61 : 54 | 2Q | 0.5
# [00:11:45] DEN : UTA | 61 : 54 | 2Q | 0.5
# [00:11:46] DEN : UTA | 61 : 54 | 2Q | 0.5
# [00:11:47] DEN : UTA | 61 : 54 | 2Q | 0.5
# [00:11:48] scoreboard not found (candidate 1/3) | clock 0.5
# [00:11:49] scoreboard not found (candidate 2/3) | clock 0.5
# [00:11:50] scoreboard not found (confirmed) | clock 0.5
# [00:11:51] scoreboard not found (confirmed) | clock 0.5
# [00:11:52] scoreboard not found (confirmed) | clock 0.5
# [00:11:53] scoreboard not found (confirmed) | clock 0.5
# [00:11:54] scoreboard not found (confirmed) | clock 0.5
# [00:11:55] scoreboard not found (confirmed) | clock 0.5
# [00:11:56] scoreboard not found (confirmed) | clock 0.5
# [00:11:57] scoreboard not found (confirmed) | clock 0.5
# [00:11:58] scoreboard not found (confirmed) | clock 0.5
# [00:11:59] scoreboard not found (confirmed) | clock 0.5
# [00:12:00] scoreboard not found (confirmed) | clock 0.5
# [00:12:01] scoreboard not found (confirmed) | clock 0.5
# [00:12:02] scoreboard not found (confirmed) | clock 0.5
#            -> long confirmed missing detected: 13 confirmed missing samples (total missing=15), OCR clock resync mode
#            -> rejected long-missing clock OCR, keep previous clock: last=00:00, raw=00:00, limit=300s
# [00:12:03] DEN : UTA | 61 : 54 | 2Q | 00:00
# [00:12:04] DEN : UTA | 61 : 54 | 2Q | 0.5
# [00:12:05] DEN : UTA | 61 : 54 | 2Q | 0.5
# [00:12:06] DEN : UTA | 61 : 54 | 2Q | 0.5
# [00:12:07] DEN : UTA | 61 : 54 | 2Q | 0.5
# [00:12:08] DEN : UTA | 61 : 54 | 2Q | 0.5
# [00:12:09] DEN : UTA | 61 : 54 | 2Q | 0.5
# [00:12:10] DEN : UTA | 61 : 54 | 2Q | 0.5
# [00:12:11] DEN : UTA | 61 : 54 | 2Q | 0.5
# [00:12:12] scoreboard not found (candidate 1/3) | clock 0.5
# [00:12:13] DEN : UTA | 61 : 55 | 2Q | 0.5
#            -> possible valid score change: 61:54 -> 61:55 (1/2 votes)
# [00:12:14] DEN : UTA | 61 : 55 | 2Q | 0.5
#            -> possible valid score change: 61:54 -> 61:55 (2/2 votes)
#            -> score change confirmed: 61:55 at 00:12:13
# [00:12:15] DEN : UTA | 61 : 55 | 2Q | 0.5
# [00:12:16] DEN : UTA | 61 : 55 | 2Q | 0.5
# [00:12:17] DEN : UTA | 61 : 55 | 2Q | 0.5
# [00:12:18] DEN : UTA | 61 : 55 | 2Q | 0.5
# [00:12:19] DEN : UTA | 61 : 55 | 2Q | 0.5
# [00:12:20] DEN : UTA | 61 : 55 | 2Q | 0.5
# [00:12:21] DEN : UTA | 61 : 55 | 2Q | 0.5
# [00:12:22] DEN : UTA | 61 : 55 | 2Q | 0.5
# [00:12:23] DEN : UTA | 61 : 55 | 2Q | 0.5
# [00:12:24] DEN : UTA | 61 : 55 | 2Q | 0.5
# [00:12:25] DEN : UTA | 61 : 55 | 2Q | 0.5
# [00:12:26] DEN : UTA | 61 : 55 | 2Q | 0.5
# [00:12:27] DEN : UTA | 61 : 55 | 2Q | 0.5
# [00:12:28] scoreboard not found (candidate 1/3) | clock 0.5
# [00:12:29] DEN : UTA | 61 : 56 | 2Q | 0.5
#            -> possible valid score change: 61:55 -> 61:56 (1/2 votes)
# [00:12:30] DEN : UTA | 61 : 56 | 2Q | 0.4
#            -> possible valid score change: 61:55 -> 61:56 (2/2 votes)
#            -> score change confirmed: 61:56 at 00:12:29
# [00:12:31] DEN : UTA | 61 : 56 | 2Q | 0.0
# [00:12:32] DEN : UTA | 61 : 56 | 2Q | 00:00
# [00:12:33] DEN : UTA | 61 : 56 | 2Q | 00:00
# [00:12:34] DEN : UTA | 61 : 56 | 2Q | 00:00
# [00:12:35] scoreboard not found (candidate 1/3) | clock 00:00
# [00:12:36] scoreboard not found (candidate 2/3) | clock 00:00
# [00:12:37] scoreboard not found (confirmed) | clock 00:00
# [00:12:38] scoreboard not found (confirmed) | clock 00:00
# [00:12:39] scoreboard not found (confirmed) | clock 00:00
# [00:12:40] scoreboard not found (confirmed) | clock 00:00
# [00:12:41] scoreboard not found (confirmed) | clock 00:00
# [00:12:42] scoreboard not found (confirmed) | clock 00:00
# [00:12:43] scoreboard not found (confirmed) | clock 00:00
# [00:12:44] scoreboard not found (confirmed) | clock 00:00
# [00:12:45] scoreboard not found (confirmed) | clock 00:00
# [00:12:46] scoreboard not found (confirmed) | clock 00:00
# [00:12:47] scoreboard not found (confirmed) | clock 00:00
# [00:12:48] scoreboard not found (confirmed) | clock 00:00
# [00:12:49] scoreboard not found (confirmed) | clock 00:00
# [00:12:50] scoreboard not found (confirmed) | clock 00:00
# [00:12:51] scoreboard not found (confirmed) | clock 00:00
# [00:12:52] scoreboard not found (confirmed) | clock 00:00
# [00:12:53] scoreboard not found (confirmed) | clock 00:00
# [00:12:54] scoreboard not found (confirmed) | clock 00:00
# [00:12:55] scoreboard not found (confirmed) | clock 00:00
# [00:12:56] scoreboard not found (confirmed) | clock 00:00
# [00:12:57] scoreboard not found (confirmed) | clock 00:00
# [00:12:58] scoreboard not found (confirmed) | clock 00:00
# [00:12:59] scoreboard not found (confirmed) | clock 00:00
# [00:13:00] scoreboard not found (confirmed) | clock 00:00
# [00:13:01] scoreboard not found (confirmed) | clock 00:00
# [00:13:02] scoreboard not found (confirmed) | clock 00:00
# [00:13:03] scoreboard not found (confirmed) | clock 00:00
#            -> long confirmed missing detected: 27 confirmed missing samples (total missing=29), OCR clock resync mode
#            -> rejected long-missing clock OCR, keep previous clock: last=00:00, raw=00:53, limit=300s
# [00:13:04] DEN : UTA | 61 : 56 | 2Q | 00:00
# [00:13:05] DEN : UTA | 61 : 56 | 2Q | 00:00
# [00:13:06] DEN : UTA | 61 : 56 | 3Q | 11:49
# [00:13:07] scoreboard not found (candidate 1/3) | clock 11:49
# [00:13:08] DEN : UTA | 61 : 56 | 3Q | 11:47
# [00:13:09] scoreboard not found (candidate 1/3) | clock 11:47
# [00:13:10] scoreboard not found (candidate 2/3) | clock 11:47
# [00:13:11] scoreboard not found (confirmed) | clock 11:47
# [00:13:12] DEN : UTA | 61 : 56 | 3Q | 11:43
# [00:13:13] DEN : UTA | 61 : 56 | 3Q | 11:42
# [00:13:14] DEN : UTA | 61 : 56 | 3Q | 11:41
# [00:13:15] DEN : UTA | 61 : 56 | 3Q | 11:40
# [00:13:16] DEN : UTA | 61 : 56 | 3Q | 11:39
# [00:13:17] DEN : UTA | 61 : 56 | 3Q | 11:38
# [00:13:18] DEN : UTA | 61 : 56 | 3Q | 11:37
# [00:13:19] DEN : UTA | 61 : 56 | 3Q | 11:36
# [00:13:20] scoreboard not found (candidate 1/3) | clock 11:36
# [00:13:21] scoreboard not found (candidate 2/3) | clock 11:36
# [00:13:22] scoreboard not found (confirmed) | clock 11:36
# [00:13:23] scoreboard not found (confirmed) | clock 11:36
# [00:13:24] DEN : UTA | 61 : 56 | 3Q | 11:31
# [00:13:25] DEN : UTA | 61 : 56 | 3Q | 11:30
# [00:13:26] DEN : UTA | 61 : 56 | 3Q | 11:29
# [00:13:27] DEN : UTA | 61 : 56 | 3Q | 11:28
# [00:13:28] DEN : UTA | 61 : 56 | 3Q | 11:27
# [00:13:29] DEN : UTA | 61 : 56 | 3Q | 11:26
# [00:13:30] DEN : UTA | 61 : 56 | 3Q | 11:25
# [00:13:31] DEN : UTA | 61 : 56 | 3Q | 11:24
# [00:13:32] DEN : UTA | 61 : 56 | 3Q | 11:23
# [00:13:33] DEN : UTA | 61 : 56 | 3Q | 11:22
# [00:13:34] DEN : UTA | 61 : 56 | 3Q | 11:22
# [00:13:35] DEN : UTA | 61 : 56 | 3Q | 11:20
# [00:13:36] DEN : UTA | 61 : 56 | 3Q | 11:19
# [00:13:37] DEN : UTA | 61 : 56 | 3Q | 11:18
# [00:13:38] DEN : UTA | 61 : 56 | 3Q | 11:17
# [00:13:39] DEN : UTA | 61 : 56 | 3Q | 11:16
# [00:13:40] DEN : UTA | 61 : 56 | 3Q | 11:15
# [00:13:41] DEN : UTA | 61 : 56 | 3Q | 11:14
# [00:13:42] DEN : UTA | 61 : 56 | 3Q | 11:13
# [00:13:43] DEN : UTA | 61 : 56 | 3Q | 11:12
# [00:13:44] DEN : UTA | 61 : 56 | 3Q | 11:11
# [00:13:45] scoreboard not found (candidate 1/3) | clock 11:11
# [00:13:46] scoreboard not found (candidate 2/3) | clock 11:11
# [00:13:47] DEN : UTA | 61 : 56 | 3Q | 11:08
# [00:13:48] DEN : UTA | 61 : 56 | 3Q | 11:07
# [00:13:49] DEN : UTA | 61 : 56 | 3Q | 11:06
# [00:13:50] DEN : UTA | 61 : 56 | 3Q | 11:05
# [00:13:51] DEN : UTA | 61 : 56 | 3Q | 11:04
# [00:13:52] DEN : UTA | 61 : 56 | 3Q | 11:03
# [00:13:53] DEN : UTA | 61 : 56 | 3Q | 11:02
# [00:13:54] DEN : UTA | 61 : 56 | 3Q | 11:01
# [00:13:55] DEN : UTA | 61 : 56 | 3Q | 11:00
# ...
# [00:22:07] DEN : UTA | 72 : 69 | 3Q | 06:11
# [00:22:08] DEN : UTA | 72 : 69 | 3Q | 06:10
# [00:22:09] DEN : UTA | 72 : 69 | 3Q | 06:09
# [00:22:10] DEN : UTA | 72 : 69 | 3Q | 06:08
# [00:22:11] DEN : UTA | 72 : 69 | 3Q | 06:07
# [00:22:12] DEN : UTA | 72 : 69 | 3Q | 06:06
# [00:22:13] DEN : UTA | 72 : 69 | 3Q | 06:05
# [00:22:14] DEN : UTA | 72 : 69 | 3Q | 06:04
# [00:22:15] DEN : UTA | 72 : 69 | 3Q | 06:03
# [00:22:16] DEN : UTA | 72 : 69 | 3Q | 06:02
# [00:22:17] DEN : UTA | 72 : 69 | 3Q | 06:01
# [00:22:18] DEN : UTA | 72 : 69 | 3Q | 06:00
# [00:22:19] DEN : UTA | 72 : 69 | 3Q | 05:59
# [00:22:20] DEN : UTA | 72 : 69 | 3Q | 05:58
# [00:22:21] DEN : UTA | 72 : 69 | 3Q | 05:57
# [00:22:22] DEN : UTA | 72 : 69 | 3Q | 05:56
# [00:22:23] DEN : UTA | 72 : 69 | 3Q | 05:55
# [00:22:24] DEN : UTA | 72 : 69 | 3Q | 05:54
# [00:22:25] DEN : UTA | 72 : 69 | 3Q | 05:53
# [00:22:26] DEN : UTA | 72 : 69 | 3Q | 05:52
# [00:22:27] DEN : UTA | 72 : 69 | 3Q | 05:51
# [00:22:28] DEN : UTA | 72 : 69 | 3Q | 05:50
# [00:22:29] DEN : UTA | 72 : 69 | 3Q | 05:49
# [00:22:30] DEN : UTA | 72 : 69 | 3Q | 05:48
# [00:22:31] DEN : UTA | 72 : 69 | 3Q | 05:47
# [00:22:32] DEN : UTA | 72 : 69 | 3Q | 05:46
# [00:22:33] DEN : UTA | 72 : 69 | 3Q | 05:46
# [00:22:34] DEN : UTA | 72 : 69 | 3Q | 05:44
# [00:22:35] DEN : UTA | 72 : 69 | 3Q | 05:44
# [00:22:36] DEN : UTA | 72 : 69 | 3Q | 05:44
# [00:22:37] DEN : UTA | 72 : 69 | 3Q | 05:44
# [00:22:38] DEN : UTA | 72 : 69 | 3Q | 05:44
# [00:22:39] DEN : UTA | 72 : 69 | 3Q | 05:44
# [00:22:40] DEN : UTA | 72 : 69 | 3Q | 05:44
# [00:22:41] DEN : UTA | 72 : 69 | 3Q | 05:44
# [00:22:42] DEN : UTA | 72 : 69 | 3Q | 05:44
# [00:22:43] DEN : UTA | 72 : 69 | 3Q | 05:44
# [00:22:44] DEN : UTA | 72 : 69 | 3Q | 05:44
# [00:22:45] DEN : UTA | 72 : 69 | 3Q | 05:44
# [00:22:46] DEN : UTA | 72 : 69 | 3Q | 05:44
# [00:22:47] DEN : UTA | 72 : 69 | 3Q | 05:44
# [00:22:48] DEN : UTA | 72 : 71 | 3Q | 05:44
#            -> possible valid score change: 72:69 -> 72:71 (1/2 votes)
# [00:22:49] DEN : UTA | 72 : 71 | 3Q | 05:44
#            -> possible valid score change: 72:69 -> 72:71 (2/2 votes)
#            -> score change confirmed: 72:71 at 00:22:48
# [00:22:50] DEN : UTA | 72 : 71 | 3Q | 05:44
# [00:22:51] DEN : UTA | 72 : 71 | 3Q | 05:44
# [00:22:52] scoreboard not found (candidate 1/3) | clock 05:44
# [00:22:53] scoreboard not found (candidate 2/3) | clock 05:44
# [00:22:54] scoreboard not found (confirmed) | clock 05:44
# [00:22:55] scoreboard not found (confirmed) | clock 05:44
# [00:22:56] DEN : UTA | 72 : 71 | 3Q | 05:44
# [00:22:57] DEN : UTA | 72 : 71 | 3Q | 05:44
# [00:22:58] DEN : UTA | 72 : 71 | 3Q | 05:44
# [00:22:59] DEN : UTA | 72 : 71 | 3Q | 05:44
# [00:23:00] scoreboard not found (candidate 1/3) | clock 05:44
# [00:23:01] scoreboard not found (candidate 2/3) | clock 05:44
# [00:23:02] scoreboard not found (confirmed) | clock 05:44
# [00:23:03] scoreboard not found (confirmed) | clock 05:44
# [00:23:04] scoreboard not found (confirmed) | clock 05:44
# [00:23:05] scoreboard not found (confirmed) | clock 05:44
# [00:23:06] scoreboard not found (confirmed) | clock 05:44
# [00:23:07] scoreboard not found (confirmed) | clock 05:44
# [00:23:08] scoreboard not found (confirmed) | clock 05:44
# [00:23:09] scoreboard not found (confirmed) | clock 05:44
# [00:23:10] scoreboard not found (confirmed) | clock 05:44
# [00:23:11] scoreboard not found (confirmed) | clock 05:44
#            -> long confirmed missing detected: 10 confirmed missing samples (total missing=12), OCR clock resync mode
#            -> rejected long-missing clock OCR, keep previous clock: last=05:44, raw=00:05, limit=300s
# [00:23:12] DEN : UTA | 72 : 71 | 3Q | 05:44
# [00:23:13] DEN : UTA | 72 : 71 | 3Q | 05:44
# [00:23:14] DEN : UTA | 72 : 71 | 3Q | 05:44
# [00:23:15] DEN : UTA | 72 : 71 | 3Q | 05:23
# [00:23:16] DEN : UTA | 72 : 71 | 3Q | 05:23
# [00:23:17] DEN : UTA | 72 : 71 | 3Q | 05:23
# [00:23:18] DEN : UTA | 72 : 71 | 3Q | 05:23
# [00:23:19] DEN : UTA | 72 : 71 | 3Q | 05:22
# [00:23:20] DEN : UTA | 72 : 71 | 3Q | 05:22
# [00:23:21] DEN : UTA | 72 : 71 | 3Q | 05:22
# [00:23:22] DEN : UTA | 72 : 71 | 3Q | 05:22
# [00:23:23] DEN : UTA | 72 : 71 | 3Q | 05:22
# [00:23:24] DEN : UTA | 72 : 71 | 3Q | 05:22
# [00:23:25] DEN : UTA | 72 : 71 | 3Q | 05:22
# [00:23:26] DEN : UTA | 72 : 71 | 3Q | 05:22
# [00:23:27] DEN : UTA | 72 : 71 | 3Q | 05:22
# [00:23:28] DEN : UTA | 72 : 71 | 3Q | 05:22
# [00:23:29] DEN : UTA | 72 : 71 | 3Q | 05:22
# [00:23:30] DEN : UTA | 72 : 71 | 3Q | 05:22
# [00:23:31] DEN : UTA | 72 : 71 | 3Q | 05:22
# [00:23:32] DEN : UTA | 72 : 71 | 3Q | 05:22
# [00:23:33] DEN : UTA | 72 : 71 | 3Q | 05:22
# [00:23:34] DEN : UTA | 72 : 71 | 3Q | 05:22
# [00:23:35] DEN : UTA | 72 : 71 | 3Q | 05:22
# [00:23:36] DEN : UTA | 72 : 71 | 3Q | 05:22
# [00:23:37] DEN : UTA | 72 : 71 | 3Q | 05:22
# [00:23:38] DEN : UTA | 72 : 71 | 3Q | 05:22
# [00:23:39] DEN : UTA | 72 : 71 | 3Q | 05:22
# [00:23:40] DEN : UTA | 72 : 71 | 3Q | 05:22
# [00:23:41] DEN : UTA | 72 : 71 | 3Q | 05:22
# [00:23:42] DEN : UTA | 72 : 71 | 3Q | 05:22
# [00:23:43] DEN : UTA | 72 : 71 | 3Q | 05:22
# [00:23:44] DEN : UTA | 72 : 71 | 3Q | 05:22
# [00:23:45] DEN : UTA | 73 : 71 | 3Q | 05:22
#            -> possible valid score change: 72:71 -> 73:71 (1/2 votes)
# [00:23:46] DEN : UTA | 73 : 71 | 3Q | 05:22
#            -> possible valid score change: 72:71 -> 73:71 (2/2 votes)
#            -> score change confirmed: 73:71 at 00:23:45
# [00:23:47] DEN : UTA | 73 : 71 | 3Q | 05:22
# [00:23:48] DEN : UTA | 73 : 71 | 3Q | 05:22
# [00:23:49] DEN : UTA | 73 : 71 | 3Q | 05:22
# [00:23:50] DEN : UTA | 73 : 71 | 3Q | 05:22
# [00:23:51] DEN : UTA | 73 : 71 | 3Q | 05:22
# [00:23:52] DEN : UTA | 73 : 71 | 3Q | 05:22
# [00:23:53] DEN : UTA | 73 : 71 | 3Q | 05:22
# [00:23:54] DEN : UTA | 73 : 71 | 3Q | 05:22
# [00:23:55] DEN : UTA | 73 : 71 | 3Q | 05:22
# [00:23:56] DEN : UTA | 73 : 71 | 3Q | 05:22
# [00:23:57] DEN : UTA | 73 : 71 | 3Q | 05:22
# [00:23:58] DEN : UTA | 73 : 71 | 3Q | 05:22
# [00:23:59] DEN : UTA | 73 : 71 | 3Q | 05:22
# [00:24:00] DEN : UTA | 73 : 71 | 3Q | 05:22
# [00:24:01] DEN : UTA | 73 : 71 | 3Q | 05:22
# [00:24:02] DEN : UTA | 73 : 71 | 3Q | 05:22
# [00:24:03] DEN : UTA | 73 : 71 | 3Q | 05:22
# [00:24:04] DEN : UTA | 73 : 71 | 3Q | 05:22
# [00:24:05] DEN : UTA | 73 : 71 | 3Q | 05:22
# [00:24:06] DEN : UTA | 73 : 71 | 3Q | 05:22
# [00:24:07] DEN : UTA | 73 : 71 | 3Q | 05:22
# [00:24:08] DEN : UTA | 73 : 71 | 3Q | 05:22
# [00:24:09] DEN : UTA | 74 : 71 | 3Q | 05:22
#            -> possible valid score change: 73:71 -> 74:71 (1/2 votes)
# [00:24:10] DEN : UTA | 74 : 71 | 3Q | 05:22
#            -> possible valid score change: 73:71 -> 74:71 (2/2 votes)
#            -> score change confirmed: 74:71 at 00:24:09
# [00:24:11] DEN : UTA | 74 : 71 | 3Q | 05:22
# [00:24:12] DEN : UTA | 74 : 71 | 3Q | 05:22
# [00:24:13] scoreboard not found (candidate 1/3) | clock 05:22
# [00:24:14] scoreboard not found (candidate 2/3) | clock 05:22
# [00:24:15] scoreboard not found (confirmed) | clock 05:22
# [00:24:16] scoreboard not found (confirmed) | clock 05:22
# [00:24:17] scoreboard not found (confirmed) | clock 05:22
# [00:24:18] scoreboard not found (confirmed) | clock 05:22
# [00:24:19] DEN : UTA | 74 : 71 | 3Q | 05:16
# [00:24:20] scoreboard not found (candidate 1/3) | clock 05:16
# [00:24:21] scoreboard not found (candidate 2/3) | clock 05:16
# [00:24:22] DEN : UTA | 74 : 71 | 3Q | 05:13
# [00:24:23] DEN : UTA | 74 : 71 | 3Q | 05:12
# [00:24:24] scoreboard not found (candidate 1/3) | clock 05:12
# [00:24:25] scoreboard not found (candidate 2/3) | clock 05:12
# [00:24:26] scoreboard not found (confirmed) | clock 05:12
# [00:24:27] scoreboard not found (confirmed) | clock 05:12
# [00:24:28] scoreboard not found (confirmed) | clock 05:12
# [00:24:29] scoreboard not found (confirmed) | clock 05:12
# [00:24:30] DEN : UTA | 74 : 71 | 3Q | 05:05
# [00:24:31] DEN : UTA | 74 : 71 | 3Q | 05:04
# [00:24:32] DEN : UTA | 74 : 71 | 3Q | 05:03
# [00:24:33] DEN : UTA | 74 : 71 | 3Q | 05:02
# [00:24:34] DEN : UTA | 74 : 71 | 3Q | 05:01
# [00:24:35] DEN : UTA | 76 : 71 | 3Q | 05:00
#            -> possible valid score change: 74:71 -> 76:71 (1/2 votes)
# [00:24:36] DEN : UTA | 77 : 71 | 3Q | 04:59
#            -> possible valid score change: 74:71 -> 77:71 (1/2 votes)
# [00:24:37] DEN : UTA | 77 : 71 | 3Q | 04:58
#            -> possible valid score change: 74:71 -> 77:71 (2/2 votes)
#            -> score change confirmed: 77:71 at 00:24:36
# [00:24:38] DEN : UTA | 77 : 71 | 3Q | 04:57
# [00:24:39] scoreboard not found (candidate 1/3) | clock 04:57
# [00:24:40] scoreboard not found (candidate 2/3) | clock 04:57
# [00:24:41] scoreboard not found (confirmed) | clock 04:57
# [00:24:42] scoreboard not found (confirmed) | clock 04:57
# [00:24:43] scoreboard not found (confirmed) | clock 04:57
# [00:24:44] DEN : UTA | 77 : 71 | 3Q | 04:51
# [00:24:45] DEN : UTA | 77 : 71 | 3Q | 04:50
# [00:24:46] DEN : UTA | 77 : 71 | 3Q | 04:49
# [00:24:47] DEN : UTA | 77 : 71 | 3Q | 04:48
# [00:24:48] DEN : UTA | 77 : 71 | 3Q | 04:47
# [00:24:49] DEN : UTA | 77 : 71 | 3Q | 04:46
# [00:24:50] DEN : UTA | 77 : 71 | 3Q | 04:45
# [00:24:51] DEN : UTA | 77 : 71 | 3Q | 04:44
# [00:24:52] DEN : UTA | 77 : 71 | 3Q | 04:43
# [00:24:53] DEN : UTA | 77 : 71 | 3Q | 04:42
# [00:24:54] DEN : UTA | 77 : 71 | 3Q | 04:42
# [00:24:55] DEN : UTA | 77 : 71 | 3Q | 04:40
# [00:24:56] DEN : UTA | 77 : 71 | 3Q | 04:39
# [00:24:57] DEN : UTA | 77 : 71 | 3Q | 04:38
# [00:24:58] DEN : UTA | 77 : 71 | 3Q | 04:37
# [00:24:59] DEN : UTA | 77 : 71 | 3Q | 04:36
# [00:25:00] scoreboard not found (candidate 1/3) | clock 04:36
# [00:25:01] scoreboard not found (candidate 2/3) | clock 04:36
# [00:25:02] scoreboard not found (confirmed) | clock 04:36
# [00:25:03] scoreboard not found (confirmed) | clock 04:36
# [00:25:04] DEN : UTA | 77 : 74 | 3Q | 04:31
#            -> possible valid score change: 77:71 -> 77:74 (1/2 votes)
# [00:25:05] scoreboard not found (candidate 1/3) | clock 04:31
# [00:25:06] scoreboard not found (candidate 2/3) | clock 04:31
# [00:25:07] scoreboard not found (confirmed) | clock 04:31
# [00:25:08] DEN : UTA | 77 : 74 | 3Q | 04:27
#            -> possible valid score change: 77:71 -> 77:74 (2/2 votes)
#            -> score change confirmed: 77:74 at 00:25:04
# [00:25:09] DEN : UTA | 77 : 74 | 3Q | 04:26
# [00:25:10] DEN : UTA | 77 : 74 | 3Q | 04:25
# [00:25:11] DEN : UTA | 77 : 74 | 3Q | 04:24
# [00:25:12] DEN : UTA | 77 : 74 | 3Q | 04:23
# [00:25:13] scoreboard not found (candidate 1/3) | clock 04:23
# [00:25:14] DEN : UTA | 77 : 74 | 3Q | 04:21
# [00:25:15] scoreboard not found (candidate 1/3) | clock 04:21
# [00:25:16] DEN : UTA | 77 : 74 | 3Q | 04:19
# [00:25:17] DEN : UTA | 77 : 74 | 3Q | 04:18
# [00:25:18] DEN : UTA | 77 : 74 | 3Q | 04:17
# [00:25:19] scoreboard not found (candidate 1/3) | clock 04:17
# [00:25:20] scoreboard not found (candidate 2/3) | clock 04:17
# [00:25:21] scoreboard not found (confirmed) | clock 04:17
# [00:25:22] scoreboard not found (confirmed) | clock 04:17
# [00:25:23] scoreboard not found (confirmed) | clock 04:17
# [00:25:24] scoreboard not found (confirmed) | clock 04:17
# [00:25:25] scoreboard not found (confirmed) | clock 04:17
# [00:25:26] scoreboard not found (confirmed) | clock 04:17
# [00:25:27] DEN : UTA | 77 : 74 | 3Q | 04:08
# [00:25:28] scoreboard not found (candidate 1/3) | clock 04:08
# [00:25:29] scoreboard not found (candidate 2/3) | clock 04:08
# [00:25:30] scoreboard not found (confirmed) | clock 04:08
# [00:25:31] scoreboard not found (confirmed) | clock 04:08
# [00:25:32] scoreboard not found (confirmed) | clock 04:08
# [00:25:33] scoreboard not found (confirmed) | clock 04:08
# [00:25:34] scoreboard not found (confirmed) | clock 04:08
# [00:25:35] scoreboard not found (confirmed) | clock 04:08
# [00:25:36] scoreboard not found (confirmed) | clock 04:08
# [00:25:37] scoreboard not found (confirmed) | clock 04:08
# [00:25:38] scoreboard not found (confirmed) | clock 04:08
# [00:25:39] scoreboard not found (confirmed) | clock 04:08
# [00:25:40] scoreboard not found (confirmed) | clock 04:08
# [00:25:41] scoreboard not found (confirmed) | clock 04:08
# [00:25:42] scoreboard not found (confirmed) | clock 04:08
# [00:25:43] scoreboard not found (confirmed) | clock 04:08
#            -> long confirmed missing detected: 14 confirmed missing samples (total missing=16), OCR clock resync mode
#            -> clock resynced after long confirmed missing: 04:08 -> 03:51 (drop=17.0s, limit=300s)
# [00:25:44] DEN : UTA | 77 : 74 | 3Q | 03:51
# [00:25:45] scoreboard not found (candidate 1/3) | clock 03:51
# [00:25:46] scoreboard not found (candidate 2/3) | clock 03:51
# [00:25:47] scoreboard not found (confirmed) | clock 03:51
# [00:25:48] scoreboard not found (confirmed) | clock 03:51
# [00:25:49] scoreboard not found (confirmed) | clock 03:51
# [00:25:50] DEN : UTA | 77 : 74 | 3Q | 03:45
# [00:25:51] DEN : UTA | 77 : 74 | 3Q | 03:44
# [00:25:52] scoreboard not found (candidate 1/3) | clock 03:44
# [00:25:53] DEN : UTA | 77 : 74 | 3Q | 03:42
# [00:25:54] scoreboard not found (candidate 1/3) | clock 03:42
# [00:25:55] scoreboard not found (candidate 2/3) | clock 03:42
# [00:25:56] scoreboard not found (confirmed) | clock 03:42
# [00:25:57] scoreboard not found (confirmed) | clock 03:42
# [00:25:58] scoreboard not found (confirmed) | clock 03:42
# [00:25:59] scoreboard not found (confirmed) | clock 03:42
# Saved: /kaggle/working/score_timeline_full_conservative_plus_decimal_v7_visible_clock_fix.csv
#
# === Score changes ===
# [00:00:59] DEN : UTA | 46 : 43 | 2Q | 06:49
# [00:01:04] DEN : UTA | 48 : 43 | 2Q | 06:44
# [00:01:17] DEN : UTA | 48 : 45 | 2Q | 06:31
# [00:01:34] DEN : UTA | 50 : 45 | 2Q | 06:14
# [00:02:32] DEN : UTA | 52 : 45 | 2Q | 05:45
# [00:03:49] DEN : UTA | 52 : 46 | 2Q | 05:25
# [00:04:58] DEN : UTA | 54 : 46 | 2Q | 04:45
# [00:05:42] DEN : UTA | 54 : 49 | 2Q | 04:44
# [00:05:57] DEN : UTA | 56 : 49 | 2Q | 04:44
# [00:06:49] DEN : UTA | 59 : 49 | 2Q | 03:16
#
# Final score: DEN 59 : 49 UTA
#    analysis_time team1 team2  team1_score  team2_score quarter game_clock
# 0       00:00:04   DEN   UTA           45           43      2Q      07:41
# 1       00:00:59   DEN   UTA           46           43      2Q      06:49
# 2       00:01:04   DEN   UTA           48           43      2Q      06:44
# 3       00:01:17   DEN   UTA           48           45      2Q      06:31
# 4       00:01:34   DEN   UTA           50           45      2Q      06:14
# 5       00:02:32   DEN   UTA           52           45      2Q      05:45
# 6       00:03:49   DEN   UTA           52           46      2Q      05:25
# 7       00:04:58   DEN   UTA           54           46      2Q      04:45
# 8       00:05:42   DEN   UTA           54           49      2Q      04:44
# 9       00:05:57   DEN   UTA           56           49      2Q      04:44
# 10      00:06:49   DEN   UTA           59           49      2Q      03:16
# 11      00:08:03   DEN   UTA           61           51      2Q      02:51
# 12      00:08:32   DEN   UTA           61           54      2Q      02:22
# 13      00:12:13   DEN   UTA           61           55      2Q        0.5
# 14      00:12:29   DEN   UTA           61           56      2Q        0.5
# 15      00:15:37   DEN   UTA           62           56      3Q      10:14
# 16      00:15:49   DEN   UTA           63           56      3Q      10:14
# 17      00:16:08   DEN   UTA           63           58      3Q      09:56
# 18      00:16:29   DEN   UTA           66           58      3Q      09:35
# 19      00:16:53   DEN   UTA           66           60      3Q      09:11
# 20      00:17:19   DEN   UTA           66           63      3Q      08:45
# 21      00:18:39   DEN   UTA           68           63      3Q      07:45
# 22      00:18:54   DEN   UTA           68           66      3Q      07:30
# 23      00:20:07   DEN   UTA           69           66      3Q      07:09
# 24      00:20:28   DEN   UTA           70           66      3Q      07:09
# 25      00:21:14   DEN   UTA           70           69      3Q      06:44
# 26      00:22:03   DEN   UTA           72           69      3Q      06:15
# 27      00:22:48   DEN   UTA           72           71      3Q      05:44
# 28      00:23:45   DEN   UTA           73           71      3Q      05:22
# 29      00:24:09   DEN   UTA           74           71      3Q      05:22
# 30      00:24:36   DEN   UTA           77           71      3Q      04:59
# 31      00:25:04   DEN   UTA           77           74      3Q      04:31

# %%
import cv2
import matplotlib.pyplot as plt

video_path = "/kaggle/input/datasets/yerinim/basketball/1_.mp4"

cap = cv2.VideoCapture(video_path)
cap.set(cv2.CAP_PROP_POS_FRAMES, 0)
ret, frame = cap.read()
cap.release()

h, w = frame.shape[:2]

# 일단 후보 crop. 안 맞으면 숫자 바꿀 거야.
crop = frame[int(h*0.83):int(h*0.90), int(w*0.73):int(w*0.84)]

plt.figure(figsize=(10, 3))
plt.imshow(cv2.cvtColor(crop, cv2.COLOR_BGR2RGB))
plt.axis("off")
plt.show()                                                          0000000000000000000000000000000000 0                              0000000000000000000000000

# %%
import os

for dirname, _, filenames in os.walk("/kaggle/input"):
    for filename in filenames:
        print(os.path.join(dirname, filename))
